# %%
cd /mnt/c/Users/rache/OneDrive - The University of Nottingham/MRes/Flow_Country_HSI_and_PSM/python_notebooks
# Out:
# /mnt/c/Users/rache/OneDrive - The University of Nottingham/MRes/Flow_Country_HSI_and_PSM/python_notebooks

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import importlib
import hyperspectral_machine_learning as hml

# %%
from hyperspectral_machine_learning.confusion_matrix import data_to_input

importlib.reload(hml)

# datasets = [
#     data_to_input('restored_2006', 'outputs/restored_2006_full_tt-first derivative-full-0.3-5-3-2022-08-09-000000.csv'), 
#     data_to_input('cross_lochs', 'outputs/cross_lochs-second derivative-full-0.3-5-3-2022-08-09-000000.csv'),
#     data_to_input('erosion', 'outputs/erosion-original-full-0.3-5-5-2022-08-09-000000.csv'),
#     data_to_input('restored_2015', 'outputs/restored_2015-original-full-0.25-5-3-2022-08-09-000000.csv')
#     ]

# datasets = [
#     data_to_input('restored_2006', 'outputs/restored_2006_full_tt-first derivative-full-0.3-5-3-2022-08-09-000000.csv')
# ]


# datasets = [
#     data_to_input('restored_2006', 'outputs/basic_confusion_matrix_predicted_2006_tt_with_fw_data.csv')
# ]

datasets = [
    data_to_input('restored_2006', 'restored_2006_tt_full_fw_top_output.csv')
]



train_test_dataset = 'train_test_data.csv'

# train_test_dataset = 'train_test_data_2006_only.csv'


merged_data = hml.confusion_matrix.merge_each_output_with_test_train(datasets, train_test_dataset)

merged_data.to_csv("outputs/merged_data_to_sort_out.csv")

# confusion_matrix = pd.read_csv('outputs/basic_confusion_matrix_predicted_2006_tt_with_fw_data.csv')

# confusion_matrix = confusion_matrix.set_index('Predicted PFT')
# producers_matrix = hml.confusion_matrix.producers_accuracy_matrix_2006_full_fw(confusion_matrix)

# users_matrix = hml.confusion_matrix.users_accuracy_matrix_2006_full_fw(producers_matrix)

# users_matrix.to_csv('outputs/2006_from_full_compared_to_train_test_fw.csv')
# # hml.confusion_matrix.merge_each_output_with_test_train(datasets, train_test_dataset)

# %%
from sklearn.metrics import accuracy_score

merged_data = pd.read_csv('outputs/merged_data_to_sort_out.csv')

sample = merged_data['Predicted PFT']
prediction = merged_data['Sample PFT']
accuracy = accuracy_score(sample, prediction)
accuracy
# Out:
# 0.7162629757785467

# %%
hml.psm.outputs('../InSAR/2006_full_joined_to_use_trough.csv', 'trough', 0.3, 5)
# Out:
# /home/rzw/.local/lib/python3.8/site-packages/sklearn/base.py:445: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_18548/1657860767.py in <module>
# ----> 1 hml.psm.outputs('../InSAR/2006_full_joined_to_use_trough.csv', 'trough', 0.3, 5)
#
# /mnt/c/Users/rache/OneDrive - The University of Nottingham/MRes/Flow_Country_HSI_and_PSM/python_notebooks/hyperspectral_machine_learning/psm.py in outputs(joined_data_csv, field_name, test_size, max_depth, kernel, num_clusters, output_directory, site_name, random_state, cv)
#      35
#      36     logistic_regression_score = logistic_regression(data)
# ---> 37     rf_test_score = random_forest(data_with_pft, field_name, predictor_train, predicted_train, predictor_test, predicted_test,
# ...

# %%
hml.psm.outputs('../InSAR/2006_full_joined_to_use_trough.csv', 'trough', 0.25, 5)
# Out:
# /home/rzw/.local/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /mnt/c/Users/rache/OneDrive - The University of Nottingham/MRes/Flow_Country_HSI_and_PSM/python_notebooks/hyperspectral_machine_learning/psm.py:135: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
#   model_results.to_file(
# ...

# %%
hml.psm.outputs('../InSAR/2006_full_joined_to_use_trough.csv', 'trough',0.3, 4)
# Out:
# /home/rzw/.local/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /mnt/c/Users/rache/OneDrive - The University of Nottingham/MRes/Flow_Country_HSI_and_PSM/python_notebooks/hyperspectral_machine_learning/psm.py:135: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
#   model_results.to_file(
# ...

# %%
hml.psm.outputs('../InSAR/2006_full_joined_to_use_trough.csv', 'trough',0.25, 4)
# Out:
# /home/rzw/.local/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /mnt/c/Users/rache/OneDrive - The University of Nottingham/MRes/Flow_Country_HSI_and_PSM/python_notebooks/hyperspectral_machine_learning/psm.py:135: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
#   model_results.to_file(
# ...

# %%
hml.psm.similarity_measures_velocity_pfts('../InSAR/2006_full_joined_trough.csv', 'Trough')
# Out:
# /mnt/c/Users/rache/OneDrive - The University of Nottingham/MRes/Flow_Country_HSI_and_PSM/python_notebooks/hyperspectral_machine_learning/psm.py:242: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, ax = plt.subplots()

# %%
hml.psm.outputs('../InSAR/2006_full_joined_to_use_peak.csv', 'peak', 0.3, 5)
# Out:
# /mnt/c/Users/rache/OneDrive - The University of Nottingham/MRes/Flow_Country_HSI_and_PSM/python_notebooks/hyperspectral_machine_learning/psm.py:135: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
#   model_results.to_file(
# /mnt/c/Users/rache/OneDrive - The University of Nottingham/MRes/Flow_Country_HSI_and_PSM/python_notebooks/hyperspectral_machine_learning/psm.py:115: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
#   model_results.to_file(
# /mnt/c/Users/rache/OneDrive - The University of Nottingham/MRes/Flow_Country_HSI_and_PSM/python_notebooks/hyperspectral_machine_learning/psm.py:96: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
#   model_results.to_file(
# ('logistic regression: 0.32772762570374686',
#  'random_forest_score, mean and sd: [0.40164928 0.41038079 0.39728353]',
# ...

# %%
hml.psm.outputs('../InSAR/2006_full_joined_to_use_peak.csv', 'peak', 0.25, 5)
# Out:
# /mnt/c/Users/rache/OneDrive - The University of Nottingham/MRes/Flow_Country_HSI_and_PSM/python_notebooks/hyperspectral_machine_learning/psm.py:135: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
#   model_results.to_file(
# /mnt/c/Users/rache/OneDrive - The University of Nottingham/MRes/Flow_Country_HSI_and_PSM/python_notebooks/hyperspectral_machine_learning/psm.py:115: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
#   model_results.to_file(
# /mnt/c/Users/rache/OneDrive - The University of Nottingham/MRes/Flow_Country_HSI_and_PSM/python_notebooks/hyperspectral_machine_learning/psm.py:96: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
#   model_results.to_file(
# ('logistic regression: 0.32772762570374686',
#  'random_forest_score, mean and sd: [0.39650655 0.41280932 0.41426492]',
# ...

# %%
hml.psm.outputs('../InSAR/2006_full_joined_to_use_peak.csv', 'peak',0.3, 4)
# Out:
# /mnt/c/Users/rache/OneDrive - The University of Nottingham/MRes/Flow_Country_HSI_and_PSM/python_notebooks/hyperspectral_machine_learning/psm.py:135: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
#   model_results.to_file(
# /mnt/c/Users/rache/OneDrive - The University of Nottingham/MRes/Flow_Country_HSI_and_PSM/python_notebooks/hyperspectral_machine_learning/psm.py:115: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
#   model_results.to_file(
# /mnt/c/Users/rache/OneDrive - The University of Nottingham/MRes/Flow_Country_HSI_and_PSM/python_notebooks/hyperspectral_machine_learning/psm.py:96: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
#   model_results.to_file(
# ('logistic regression: 0.32772762570374686',
#  'random_forest_score, mean and sd: [0.3907349  0.40237691 0.3953432 ]',
# ...

# %%
hml.psm.outputs('../InSAR/2006_full_joined_to_use_peak.csv', 'peak',0.25, 4)
# Out:
# /mnt/c/Users/rache/OneDrive - The University of Nottingham/MRes/Flow_Country_HSI_and_PSM/python_notebooks/hyperspectral_machine_learning/psm.py:135: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
#   model_results.to_file(
# /mnt/c/Users/rache/OneDrive - The University of Nottingham/MRes/Flow_Country_HSI_and_PSM/python_notebooks/hyperspectral_machine_learning/psm.py:115: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
#   model_results.to_file(
# /mnt/c/Users/rache/OneDrive - The University of Nottingham/MRes/Flow_Country_HSI_and_PSM/python_notebooks/hyperspectral_machine_learning/psm.py:96: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
#   model_results.to_file(
# ('logistic regression: 0.32772762570374686',
#  'random_forest_score, mean and sd: [0.39592431 0.41804949 0.39243086]',
# ...

# %%
hml.psm.similarity_measures_velocity_pfts('../InSAR/2006_full_joined_to_use_peak.csv', 'Peak')
# Out:
# /mnt/c/Users/rache/OneDrive - The University of Nottingham/MRes/Flow_Country_HSI_and_PSM/python_notebooks/hyperspectral_machine_learning/psm.py:242: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, ax = plt.subplots()

# %%
hml.psm.outputs('../InSAR/2006_full_joined_to_use_amplitude.csv', 'amplitude', 0.3, 5)
# Out:
# /mnt/c/Users/rache/OneDrive - The University of Nottingham/MRes/Flow_Country_HSI_and_PSM/python_notebooks/hyperspectral_machine_learning/psm.py:135: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
#   model_results.to_file(
# /mnt/c/Users/rache/OneDrive - The University of Nottingham/MRes/Flow_Country_HSI_and_PSM/python_notebooks/hyperspectral_machine_learning/psm.py:115: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
#   model_results.to_file(
# /mnt/c/Users/rache/OneDrive - The University of Nottingham/MRes/Flow_Country_HSI_and_PSM/python_notebooks/hyperspectral_machine_learning/psm.py:96: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
#   model_results.to_file(
# ('logistic regression: 0.3278974956319161',
#  'random_forest_score, mean and sd: [0.39946641 0.39291778 0.39704099]',
# ...

# %%
hml.psm.outputs('../InSAR/2006_full_joined_to_use_amplitude.csv', 'amplitude', 0.25, 5)
# Out:
# /mnt/c/Users/rache/OneDrive - The University of Nottingham/MRes/Flow_Country_HSI_and_PSM/python_notebooks/hyperspectral_machine_learning/psm.py:135: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
#   model_results.to_file(
# /mnt/c/Users/rache/OneDrive - The University of Nottingham/MRes/Flow_Country_HSI_and_PSM/python_notebooks/hyperspectral_machine_learning/psm.py:115: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
#   model_results.to_file(
# /mnt/c/Users/rache/OneDrive - The University of Nottingham/MRes/Flow_Country_HSI_and_PSM/python_notebooks/hyperspectral_machine_learning/psm.py:96: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
#   model_results.to_file(
# ('logistic regression: 0.3278974956319161',
#  'random_forest_score, mean and sd: [0.40232897 0.41339156 0.3930131 ]',
# ...

# %%
hml.psm.outputs('../InSAR/2006_full_joined_to_use_amplitude.csv', 'amplitude',0.3, 4)
# Out:
# /mnt/c/Users/rache/OneDrive - The University of Nottingham/MRes/Flow_Country_HSI_and_PSM/python_notebooks/hyperspectral_machine_learning/psm.py:135: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
#   model_results.to_file(
# /mnt/c/Users/rache/OneDrive - The University of Nottingham/MRes/Flow_Country_HSI_and_PSM/python_notebooks/hyperspectral_machine_learning/psm.py:115: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
#   model_results.to_file(
# /mnt/c/Users/rache/OneDrive - The University of Nottingham/MRes/Flow_Country_HSI_and_PSM/python_notebooks/hyperspectral_machine_learning/psm.py:96: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
#   model_results.to_file(
# ('logistic regression: 0.3278974956319161',
#  'random_forest_score, mean and sd: [0.36817851 0.38442881 0.37642493]',
# ...

# %%
hml.psm.outputs('../InSAR/2006_full_joined_to_use_amplitude.csv', 'amplitude',0.25, 4)
# Out:
# /mnt/c/Users/rache/OneDrive - The University of Nottingham/MRes/Flow_Country_HSI_and_PSM/python_notebooks/hyperspectral_machine_learning/psm.py:135: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
#   model_results.to_file(
# /mnt/c/Users/rache/OneDrive - The University of Nottingham/MRes/Flow_Country_HSI_and_PSM/python_notebooks/hyperspectral_machine_learning/psm.py:115: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
#   model_results.to_file(
# /mnt/c/Users/rache/OneDrive - The University of Nottingham/MRes/Flow_Country_HSI_and_PSM/python_notebooks/hyperspectral_machine_learning/psm.py:96: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
#   model_results.to_file(
# ('logistic regression: 0.3278974956319161',
#  'random_forest_score, mean and sd: [0.37088792 0.38049491 0.38282387]',
# ...

# %%
hml.psm.similarity_measures_velocity_pfts('../InSAR/2006_full_joined_to_use_amplitude.csv', 'Amplitude')
# Out:
# /mnt/c/Users/rache/OneDrive - The University of Nottingham/MRes/Flow_Country_HSI_and_PSM/python_notebooks/hyperspectral_machine_learning/psm.py:242: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, ax = plt.subplots()

# %%
hml.psm.outputs('../InSAR/2006_full_joined_to_use_velocity.csv', 'velocity', 0.3, 5)
# Out:
# /mnt/c/Users/rache/OneDrive - The University of Nottingham/MRes/Flow_Country_HSI_and_PSM/python_notebooks/hyperspectral_machine_learning/psm.py:135: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
#   model_results.to_file(
# /mnt/c/Users/rache/OneDrive - The University of Nottingham/MRes/Flow_Country_HSI_and_PSM/python_notebooks/hyperspectral_machine_learning/psm.py:115: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
#   model_results.to_file(
# /mnt/c/Users/rache/OneDrive - The University of Nottingham/MRes/Flow_Country_HSI_and_PSM/python_notebooks/hyperspectral_machine_learning/psm.py:96: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
#   model_results.to_file(
# ('logistic regression: 0.3278974956319161',
#  'random_forest_score, mean and sd: [0.4278438  0.41474654 0.41935484]',
# ...

# %%
hml.psm.outputs('../InSAR/2006_full_joined_to_use_velocity.csv', 'velocity', 0.25, 5)
# Out:
# /mnt/c/Users/rache/OneDrive - The University of Nottingham/MRes/Flow_Country_HSI_and_PSM/python_notebooks/hyperspectral_machine_learning/psm.py:135: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
#   model_results.to_file(
# /mnt/c/Users/rache/OneDrive - The University of Nottingham/MRes/Flow_Country_HSI_and_PSM/python_notebooks/hyperspectral_machine_learning/psm.py:115: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
#   model_results.to_file(
# /mnt/c/Users/rache/OneDrive - The University of Nottingham/MRes/Flow_Country_HSI_and_PSM/python_notebooks/hyperspectral_machine_learning/psm.py:96: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
#   model_results.to_file(
# ('logistic regression: 0.3278974956319161',
#  'random_forest_score, mean and sd: [0.41746725 0.42066958 0.41106259]',
# ...

# %%
hml.psm.outputs('../InSAR/2006_full_joined_to_use_velocity.csv', 'velocity',0.3, 4)
# Out:
# /mnt/c/Users/rache/OneDrive - The University of Nottingham/MRes/Flow_Country_HSI_and_PSM/python_notebooks/hyperspectral_machine_learning/psm.py:135: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
#   model_results.to_file(
# /mnt/c/Users/rache/OneDrive - The University of Nottingham/MRes/Flow_Country_HSI_and_PSM/python_notebooks/hyperspectral_machine_learning/psm.py:115: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
#   model_results.to_file(
# /mnt/c/Users/rache/OneDrive - The University of Nottingham/MRes/Flow_Country_HSI_and_PSM/python_notebooks/hyperspectral_machine_learning/psm.py:96: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
#   model_results.to_file(
# ('logistic regression: 0.3278974956319161',
#  'random_forest_score, mean and sd: [0.41838467 0.38588407 0.40019403]',
# ...

# %%
hml.psm.outputs('../InSAR/2006_full_joined_to_use_velocity.csv', 'velocity',0.25, 4)
# Out:
# /mnt/c/Users/rache/OneDrive - The University of Nottingham/MRes/Flow_Country_HSI_and_PSM/python_notebooks/hyperspectral_machine_learning/psm.py:135: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
#   model_results.to_file(
# /mnt/c/Users/rache/OneDrive - The University of Nottingham/MRes/Flow_Country_HSI_and_PSM/python_notebooks/hyperspectral_machine_learning/psm.py:115: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
#   model_results.to_file(
# /mnt/c/Users/rache/OneDrive - The University of Nottingham/MRes/Flow_Country_HSI_and_PSM/python_notebooks/hyperspectral_machine_learning/psm.py:96: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
#   model_results.to_file(
# ('logistic regression: 0.3278974956319161',
#  'random_forest_score, mean and sd: [0.39475983 0.3985444  0.40058224]',
# ...

# %%
hml.psm.similarity_measures_velocity_pfts('../InSAR/2006_full_joined_to_use_velocity.csv', 'Velocity')
# Out:
# /mnt/c/Users/rache/OneDrive - The University of Nottingham/MRes/Flow_Country_HSI_and_PSM/python_notebooks/hyperspectral_machine_learning/psm.py:242: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, ax = plt.subplots()

# %%
import geopandas

data = pd.read_csv('../fieldwork/fieldsites_post_fw.csv')
data['geometry'] = geopandas.GeoSeries.from_wkt(data['geometry'])
data_gdf = geopandas.GeoDataFrame(data, geometry='geometry')


data_gdf.to_file('../fieldwork/restored_2006_2_for_random_sites_post_fw.shp')
# Out:
# /tmp/ipykernel_18548/527282002.py:8: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
#   data_gdf.to_file('../fieldwork/restored_2006_2_for_random_sites_post_fw.shp')
