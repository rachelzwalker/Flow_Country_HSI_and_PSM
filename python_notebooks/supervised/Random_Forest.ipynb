# %%
cd /mnt/c/Users/rache/OneDrive - The University of Nottingham/MRes/Flow_Country_HSI_and_PSM/python_notebooks
# Out:
# /mnt/c/Users/rache/OneDrive - The University of Nottingham/MRes/Flow_Country_HSI_and_PSM/python_notebooks

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import importlib
import hyperspectral_machine_learning as hml

from hyperspectral_machine_learning.random_forest import original_data_transformation, derivative_data_transformation

importlib.reload(hml)

# hml.random_forest.original_to_geo_dataframes('restored_2006_6_classes_for_ML.csv', 0.3, max_depth = 5)
# hml.train_test_data.x_and_y_train_test_vis('transformed_spectral_signatures/first_derivative_98_sample.csv', test_size=0.3)


# hml.random_forest.random_forest_results(hml.random_forest.original_data_transformation('original', 'restored_2006_6_classes_for_ML.csv'), test_size=0.3, max_depth=5)
# will need to update with the transformations for the train_test dataset
data_transformations = [
        original_data_transformation('original', 'train_test_data_full.csv', 'erosion_gdf2.csv'),
        derivative_data_transformation('first derivative', 'transformed_spectral_signatures/first_derivative_98_sample_train_test.csv', 'transformed_spectral_signatures/first_derivative_erosion.csv'),
        derivative_data_transformation('second derivative', 'transformed_spectral_signatures/second_derivative_98_sample_train_test.csv', 'transformed_spectral_signatures/second_derivative_erosion.csv'),
        derivative_data_transformation('continuum removal', 'transformed_spectral_signatures/BDNA_train_test.csv', 'transformed_spectral_signatures/BDNA_train_test_erosion.csv')
    ]


hml.random_forest.random_forest_csv_and_shape_file_outputs('erosion_updated', data_transformations, test_size=0.3, max_depth=5, output_directory='outputs')
# hml.random_forest.random_forest_results(data_transformations, complete_dataset, test_size=0.3, max_depth=5)

# data_transformations # when run, pft returns a number. Also, how does the data_transformations code run when there is no hml.random...
# Out:
# /home/rzw/.local/lib/python3.8/site-packages/sklearn/base.py:488: FutureWarning: The feature names should match those that were passed during fit. Starting version 1.2, an error will be raised.
# Feature names unseen at fit time:
# - 0
# - 1
# - 10
# - 100
# - 101
# - ...
# Feature names seen at fit time, yet now missing:
# - band1
# - band10
# - band100
# - band101
# - band102
# - ...
#
#   warnings.warn(message, FutureWarning)
# /home/rzw/.local/lib/python3.8/site-packages/sklearn/base.py:488: FutureWarning: The feature names should match those that were passed during fit. Starting version 1.2, an error will be raised.
# Feature names unseen at fit time:
# - 10
# - 11
# - 12
# - 13
# - 14
# - ...
# Feature names seen at fit time, yet now missing:
# - band10
# - band11
# - band12
# - band13
# - band14
# - ...
#
#   warnings.warn(message, FutureWarning)
# /home/rzw/.local/lib/python3.8/site-packages/sklearn/base.py:488: FutureWarning: The feature names should match those that were passed during fit. Starting version 1.2, an error will be raised.
# Feature names unseen at fit time:
# - 62
# - 63
# - 64
# - 65
# - 66
# - ...
# Feature names seen at fit time, yet now missing:
# - band63
# - band64
# - band65
# - band66
# - band67
# - ...
#
#   warnings.warn(message, FutureWarning)
# /home/rzw/.local/lib/python3.8/site-packages/sklearn/base.py:488: FutureWarning: The feature names should match those that were passed during fit. Starting version 1.2, an error will be raised.
# Feature names unseen at fit time:
# - 100
# - 101
# - 102
# - 103
# - 104
# - ...
# Feature names seen at fit time, yet now missing:
# - band100
# - band101
# - band102
# - band103
# - band104
# - ...
#
#   warnings.warn(message, FutureWarning)
# /home/rzw/.local/lib/python3.8/site-packages/sklearn/base.py:488: FutureWarning: The feature names should match those that were passed during fit. Starting version 1.2, an error will be raised.
# Feature names unseen at fit time:
# - 186
# - 187
# - 188
# - 189
# - 190
# - ...
# Feature names seen at fit time, yet now missing:
# - band187
# - band188
# - band189
# - band190
# - band191
# - ...
#
#   warnings.warn(message, FutureWarning)
# /home/rzw/.local/lib/python3.8/site-packages/sklearn/base.py:488: FutureWarning: The feature names should match those that were passed during fit. Starting version 1.2, an error will be raised.
# Feature names unseen at fit time:
# - 0
# - 1
# - 10
# - 100
# - 101
# - ...
# Feature names seen at fit time, yet now missing:
# - band1
# - band10
# - band100
# - band101
# - band102
# - ...
#
#   warnings.warn(message, FutureWarning)
# /home/rzw/.local/lib/python3.8/site-packages/sklearn/base.py:488: FutureWarning: The feature names should match those that were passed during fit. Starting version 1.2, an error will be raised.
# Feature names unseen at fit time:
# - 10
# - 11
# - 12
# - 13
# - 14
# - ...
# Feature names seen at fit time, yet now missing:
# - band10
# - band11
# - band12
# - band13
# - band14
# - ...
#
#   warnings.warn(message, FutureWarning)
# /home/rzw/.local/lib/python3.8/site-packages/sklearn/base.py:488: FutureWarning: The feature names should match those that were passed during fit. Starting version 1.2, an error will be raised.
# Feature names unseen at fit time:
# - 62
# - 63
# - 64
# - 65
# - 66
# - ...
# Feature names seen at fit time, yet now missing:
# - band63
# - band64
# - band65
# - band66
# - band67
# - ...
#
#   warnings.warn(message, FutureWarning)
# /home/rzw/.local/lib/python3.8/site-packages/sklearn/base.py:488: FutureWarning: The feature names should match those that were passed during fit. Starting version 1.2, an error will be raised.
# Feature names unseen at fit time:
# - 100
# - 101
# - 102
# - 103
# - 104
# - ...
# Feature names seen at fit time, yet now missing:
# - band100
# - band101
# - band102
# - band103
# - band104
# - ...
#
#   warnings.warn(message, FutureWarning)
# /home/rzw/.local/lib/python3.8/site-packages/sklearn/base.py:488: FutureWarning: The feature names should match those that were passed during fit. Starting version 1.2, an error will be raised.
# Feature names unseen at fit time:
# - 186
# - 187
# - 188
# - 189
# - 190
# - ...
# Feature names seen at fit time, yet now missing:
# - band187
# - band188
# - band189
# - band190
# - band191
# - ...
#
#   warnings.warn(message, FutureWarning)
# /home/rzw/.local/lib/python3.8/site-packages/sklearn/base.py:488: FutureWarning: The feature names should match those that were passed during fit. Starting version 1.2, an error will be raised.
# Feature names unseen at fit time:
# - 0
# - 1
# - 10
# - 100
# - 101
# - ...
# Feature names seen at fit time, yet now missing:
# - band1
# - band10
# - band100
# - band101
# - band102
# - ...
#
#   warnings.warn(message, FutureWarning)
# /home/rzw/.local/lib/python3.8/site-packages/sklearn/base.py:488: FutureWarning: The feature names should match those that were passed during fit. Starting version 1.2, an error will be raised.
# Feature names unseen at fit time:
# - 10
# - 11
# - 12
# - 13
# - 14
# - ...
# Feature names seen at fit time, yet now missing:
# - band10
# - band11
# - band12
# - band13
# - band14
# - ...
#
#   warnings.warn(message, FutureWarning)
# /home/rzw/.local/lib/python3.8/site-packages/sklearn/base.py:488: FutureWarning: The feature names should match those that were passed during fit. Starting version 1.2, an error will be raised.
# Feature names unseen at fit time:
# - 62
# - 63
# - 64
# - 65
# - 66
# - ...
# Feature names seen at fit time, yet now missing:
# - band63
# - band64
# - band65
# - band66
# - band67
# - ...
#
#   warnings.warn(message, FutureWarning)
# /home/rzw/.local/lib/python3.8/site-packages/sklearn/base.py:488: FutureWarning: The feature names should match those that were passed during fit. Starting version 1.2, an error will be raised.
# Feature names unseen at fit time:
# - 100
# - 101
# - 102
# - 103
# - 104
# - ...
# Feature names seen at fit time, yet now missing:
# - band100
# - band101
# - band102
# - band103
# - band104
# - ...
#
#   warnings.warn(message, FutureWarning)
# /home/rzw/.local/lib/python3.8/site-packages/sklearn/base.py:488: FutureWarning: The feature names should match those that were passed during fit. Starting version 1.2, an error will be raised.
# Feature names unseen at fit time:
# - 186
# - 187
# - 188
# - 189
# - 190
# - ...
# Feature names seen at fit time, yet now missing:
# - band187
# - band188
# - band189
# - band190
# - band191
# - ...
#
#   warnings.warn(message, FutureWarning)
# /mnt/c/Users/rache/OneDrive - The University of Nottingham/MRes/Flow_Country_HSI_and_PSM/python_notebooks/hyperspectral_machine_learning/random_forest.py:40: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
#   row['model_result'].to_file(f"{output_directory}/{site_name}-{row['data_transformation']}-{row['spectrum']}-{test_size}-{max_depth}-{cv}-{formatted_date}.shp")
# /mnt/c/Users/rache/OneDrive - The University of Nottingham/MRes/Flow_Country_HSI_and_PSM/python_notebooks/hyperspectral_machine_learning/random_forest.py:40: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
#   row['model_result'].to_file(f"{output_directory}/{site_name}-{row['data_transformation']}-{row['spectrum']}-{test_size}-{max_depth}-{cv}-{formatted_date}.shp")
# /mnt/c/Users/rache/OneDrive - The University of Nottingham/MRes/Flow_Country_HSI_and_PSM/python_notebooks/hyperspectral_machine_learning/random_forest.py:40: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
#   row['model_result'].to_file(f"{output_directory}/{site_name}-{row['data_transformation']}-{row['spectrum']}-{test_size}-{max_depth}-{cv}-{formatted_date}.shp")
# /mnt/c/Users/rache/OneDrive - The University of Nottingham/MRes/Flow_Country_HSI_and_PSM/python_notebooks/hyperspectral_machine_learning/random_forest.py:40: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
#   row['model_result'].to_file(f"{output_directory}/{site_name}-{row['data_transformation']}-{row['spectrum']}-{test_size}-{max_depth}-{cv}-{formatted_date}.shp")
# /mnt/c/Users/rache/OneDrive - The University of Nottingham/MRes/Flow_Country_HSI_and_PSM/python_notebooks/hyperspectral_machine_learning/random_forest.py:40: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
#   row['model_result'].to_file(f"{output_directory}/{site_name}-{row['data_transformation']}-{row['spectrum']}-{test_size}-{max_depth}-{cv}-{formatted_date}.shp")
#                                          model_result spectrum  \
# 0          POINTID                        geometry...     full
# 1          POINTID                        geometry...      VIS
# 2          POINTID                        geometry...       RE
# 3          POINTID                        geometry...      NIR
# 4          POINTID                        geometry...     SWIR
# 5                                geometry   clf_pr...     full
# 6                                geometry   clf_pr...      VIS
# 7                                geometry   clf_pr...       RE
# 8                                geometry   clf_pr...      NIR
# 9                                geometry   clf_pr...     SWIR
# 10                               geometry   clf_pr...     full
# 11                               geometry   clf_pr...      VIS
# 12                               geometry   clf_pr...       RE
# 13                               geometry   clf_pr...      NIR
# 14                               geometry   clf_pr...     SWIR
# 15                               geometry   clf_pr...     full
# 16                               geometry   clf_pr...      VIS
# 17                               geometry   clf_pr...       RE
# 18                               geometry   clf_pr...      NIR
# 19                               geometry clf_pred...     SWIR
#
#    data_transformation  accuracy_mean  accuracy_standard_deviation
# 0             original       0.679185                     0.014260
# 1             original       0.607071                     0.034715
# 2             original       0.563618                     0.019642
# 3             original       0.572239                     0.005186
# 4             original       0.589630                     0.009227
# 5     first derivative       0.710870                     0.042266
# 6     first derivative       0.598176                     0.023132
# 7     first derivative       0.514393                     0.031755
# 8     first derivative       0.586732                     0.015603
# 9     first derivative       0.624188                     0.030557
# 10   second derivative       0.662019                     0.067460
# 11   second derivative       0.598226                     0.050655
# 12   second derivative       0.601099                     0.025408
# 13   second derivative       0.592604                     0.029123
# 14   second derivative       0.607046                     0.030442
# 15   continuum removal       0.577886                     0.040463
# 16   continuum removal       0.479860                     0.023435
# 17   continuum removal       0.494053                     0.044475
# 18   continuum removal       0.528861                     0.012322
# 19   continuum removal       0.574988                     0.038412

# %%
hml.random_forest.random_forest_csv_and_shape_file_outputs('erosion_updated', data_transformations, test_size=0.25, max_depth=5, output_directory='outputs')
# Out:
# /home/rzw/.local/lib/python3.8/site-packages/sklearn/base.py:488: FutureWarning: The feature names should match those that were passed during fit. Starting version 1.2, an error will be raised.
# Feature names unseen at fit time:
# - 0
# - 1
# - 10
# - 100
# - 101
# - ...
# Feature names seen at fit time, yet now missing:
# - band1
# - band10
# - band100
# - band101
# - band102
# - ...
#
#   warnings.warn(message, FutureWarning)
# /home/rzw/.local/lib/python3.8/site-packages/sklearn/base.py:488: FutureWarning: The feature names should match those that were passed during fit. Starting version 1.2, an error will be raised.
# Feature names unseen at fit time:
# - 10
# - 11
# - 12
# - 13
# - 14
# - ...
# Feature names seen at fit time, yet now missing:
# - band10
# - band11
# - band12
# - band13
# - band14
# - ...
#
#   warnings.warn(message, FutureWarning)
# /home/rzw/.local/lib/python3.8/site-packages/sklearn/base.py:488: FutureWarning: The feature names should match those that were passed during fit. Starting version 1.2, an error will be raised.
# Feature names unseen at fit time:
# - 62
# - 63
# - 64
# - 65
# - 66
# - ...
# Feature names seen at fit time, yet now missing:
# - band63
# - band64
# - band65
# - band66
# - band67
# - ...
#
#   warnings.warn(message, FutureWarning)
# /home/rzw/.local/lib/python3.8/site-packages/sklearn/base.py:488: FutureWarning: The feature names should match those that were passed during fit. Starting version 1.2, an error will be raised.
# Feature names unseen at fit time:
# - 100
# - 101
# - 102
# - 103
# - 104
# - ...
# Feature names seen at fit time, yet now missing:
# - band100
# - band101
# - band102
# - band103
# - band104
# - ...
#
#   warnings.warn(message, FutureWarning)
# /home/rzw/.local/lib/python3.8/site-packages/sklearn/base.py:488: FutureWarning: The feature names should match those that were passed during fit. Starting version 1.2, an error will be raised.
# Feature names unseen at fit time:
# - 186
# - 187
# - 188
# - 189
# - 190
# - ...
# Feature names seen at fit time, yet now missing:
# - band187
# - band188
# - band189
# - band190
# - band191
# - ...
#
#   warnings.warn(message, FutureWarning)
# /home/rzw/.local/lib/python3.8/site-packages/sklearn/base.py:488: FutureWarning: The feature names should match those that were passed during fit. Starting version 1.2, an error will be raised.
# Feature names unseen at fit time:
# - 0
# - 1
# - 10
# - 100
# - 101
# - ...
# Feature names seen at fit time, yet now missing:
# - band1
# - band10
# - band100
# - band101
# - band102
# - ...
#
#   warnings.warn(message, FutureWarning)
# /home/rzw/.local/lib/python3.8/site-packages/sklearn/base.py:488: FutureWarning: The feature names should match those that were passed during fit. Starting version 1.2, an error will be raised.
# Feature names unseen at fit time:
# - 10
# - 11
# - 12
# - 13
# - 14
# - ...
# Feature names seen at fit time, yet now missing:
# - band10
# - band11
# - band12
# - band13
# - band14
# - ...
#
#   warnings.warn(message, FutureWarning)
# /home/rzw/.local/lib/python3.8/site-packages/sklearn/base.py:488: FutureWarning: The feature names should match those that were passed during fit. Starting version 1.2, an error will be raised.
# Feature names unseen at fit time:
# - 62
# - 63
# - 64
# - 65
# - 66
# - ...
# Feature names seen at fit time, yet now missing:
# - band63
# - band64
# - band65
# - band66
# - band67
# - ...
#
#   warnings.warn(message, FutureWarning)
# /home/rzw/.local/lib/python3.8/site-packages/sklearn/base.py:488: FutureWarning: The feature names should match those that were passed during fit. Starting version 1.2, an error will be raised.
# Feature names unseen at fit time:
# - 100
# - 101
# - 102
# - 103
# - 104
# - ...
# Feature names seen at fit time, yet now missing:
# - band100
# - band101
# - band102
# - band103
# - band104
# - ...
#
#   warnings.warn(message, FutureWarning)
# /home/rzw/.local/lib/python3.8/site-packages/sklearn/base.py:488: FutureWarning: The feature names should match those that were passed during fit. Starting version 1.2, an error will be raised.
# Feature names unseen at fit time:
# - 186
# - 187
# - 188
# - 189
# - 190
# - ...
# Feature names seen at fit time, yet now missing:
# - band187
# - band188
# - band189
# - band190
# - band191
# - ...
#
#   warnings.warn(message, FutureWarning)
# /home/rzw/.local/lib/python3.8/site-packages/sklearn/base.py:488: FutureWarning: The feature names should match those that were passed during fit. Starting version 1.2, an error will be raised.
# Feature names unseen at fit time:
# - 0
# - 1
# - 10
# - 100
# - 101
# - ...
# Feature names seen at fit time, yet now missing:
# - band1
# - band10
# - band100
# - band101
# - band102
# - ...
#
#   warnings.warn(message, FutureWarning)
# /home/rzw/.local/lib/python3.8/site-packages/sklearn/base.py:488: FutureWarning: The feature names should match those that were passed during fit. Starting version 1.2, an error will be raised.
# Feature names unseen at fit time:
# - 10
# - 11
# - 12
# - 13
# - 14
# - ...
# Feature names seen at fit time, yet now missing:
# - band10
# - band11
# - band12
# - band13
# - band14
# - ...
#
#   warnings.warn(message, FutureWarning)
# /home/rzw/.local/lib/python3.8/site-packages/sklearn/base.py:488: FutureWarning: The feature names should match those that were passed during fit. Starting version 1.2, an error will be raised.
# Feature names unseen at fit time:
# - 62
# - 63
# - 64
# - 65
# - 66
# - ...
# Feature names seen at fit time, yet now missing:
# - band63
# - band64
# - band65
# - band66
# - band67
# - ...
#
#   warnings.warn(message, FutureWarning)
# /home/rzw/.local/lib/python3.8/site-packages/sklearn/base.py:488: FutureWarning: The feature names should match those that were passed during fit. Starting version 1.2, an error will be raised.
# Feature names unseen at fit time:
# - 100
# - 101
# - 102
# - 103
# - 104
# - ...
# Feature names seen at fit time, yet now missing:
# - band100
# - band101
# - band102
# - band103
# - band104
# - ...
#
#   warnings.warn(message, FutureWarning)
# /home/rzw/.local/lib/python3.8/site-packages/sklearn/base.py:488: FutureWarning: The feature names should match those that were passed during fit. Starting version 1.2, an error will be raised.
# Feature names unseen at fit time:
# - 186
# - 187
# - 188
# - 189
# - 190
# - ...
# Feature names seen at fit time, yet now missing:
# - band187
# - band188
# - band189
# - band190
# - band191
# - ...
#
#   warnings.warn(message, FutureWarning)
# /mnt/c/Users/rache/OneDrive - The University of Nottingham/MRes/Flow_Country_HSI_and_PSM/python_notebooks/hyperspectral_machine_learning/random_forest.py:40: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
#   row['model_result'].to_file(f"{output_directory}/{site_name}-{row['data_transformation']}-{row['spectrum']}-{test_size}-{max_depth}-{cv}-{formatted_date}.shp")
# /mnt/c/Users/rache/OneDrive - The University of Nottingham/MRes/Flow_Country_HSI_and_PSM/python_notebooks/hyperspectral_machine_learning/random_forest.py:40: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
#   row['model_result'].to_file(f"{output_directory}/{site_name}-{row['data_transformation']}-{row['spectrum']}-{test_size}-{max_depth}-{cv}-{formatted_date}.shp")
# /mnt/c/Users/rache/OneDrive - The University of Nottingham/MRes/Flow_Country_HSI_and_PSM/python_notebooks/hyperspectral_machine_learning/random_forest.py:40: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
#   row['model_result'].to_file(f"{output_directory}/{site_name}-{row['data_transformation']}-{row['spectrum']}-{test_size}-{max_depth}-{cv}-{formatted_date}.shp")
# /mnt/c/Users/rache/OneDrive - The University of Nottingham/MRes/Flow_Country_HSI_and_PSM/python_notebooks/hyperspectral_machine_learning/random_forest.py:40: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
#   row['model_result'].to_file(f"{output_directory}/{site_name}-{row['data_transformation']}-{row['spectrum']}-{test_size}-{max_depth}-{cv}-{formatted_date}.shp")
# /mnt/c/Users/rache/OneDrive - The University of Nottingham/MRes/Flow_Country_HSI_and_PSM/python_notebooks/hyperspectral_machine_learning/random_forest.py:40: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
#   row['model_result'].to_file(f"{output_directory}/{site_name}-{row['data_transformation']}-{row['spectrum']}-{test_size}-{max_depth}-{cv}-{formatted_date}.shp")
#                                          model_result spectrum  \
# 0          POINTID                        geometry...     full
# 1          POINTID                        geometry...      VIS
# 2          POINTID                        geometry...       RE
# 3          POINTID                        geometry...      NIR
# 4          POINTID                        geometry...     SWIR
# 5                                geometry   clf_pr...     full
# 6                                geometry   clf_pr...      VIS
# 7                                geometry   clf_pr...       RE
# 8                                geometry   clf_pr...      NIR
# 9                                geometry   clf_pr...     SWIR
# 10                               geometry   clf_pr...     full
# 11                               geometry   clf_pr...      VIS
# 12                               geometry   clf_pr...       RE
# 13                               geometry   clf_pr...      NIR
# 14                               geometry   clf_pr...     SWIR
# 15                               geometry clf_pred...     full
# 16                               geometry   clf_pr...      VIS
# 17                               geometry   clf_pr...       RE
# 18                               geometry   clf_pr...      NIR
# 19                               geometry clf_pred...     SWIR
#
#    data_transformation  accuracy_mean  accuracy_standard_deviation
# 0             original       0.630978                     0.011593
# 1             original       0.593213                     0.028082
# 2             original       0.530928                     0.021869
# 3             original       0.530999                     0.018305
# 4             original       0.558849                     0.057634
# 5     first derivative       0.641323                     0.043641
# 6     first derivative       0.500143                     0.047926
# 7     first derivative       0.482567                     0.039458
# 8     first derivative       0.572380                     0.018227
# 9     first derivative       0.606995                     0.029099
# 10   second derivative       0.669172                     0.059758
# 11   second derivative       0.617375                     0.027488
# 12   second derivative       0.617519                     0.070734
# 13   second derivative       0.555412                     0.050800
# 14   second derivative       0.617340                     0.066268
# 15   continuum removal       0.672430                     0.025466
# 16   continuum removal       0.500143                     0.041594
# 17   continuum removal       0.486218                     0.042155
# 18   continuum removal       0.593249                     0.048206
# 19   continuum removal       0.610252                     0.042392

# %%
hml.random_forest.random_forest_csv_and_shape_file_outputs('erosion_updated', data_transformations, test_size=0.3, max_depth=4, output_directory='outputs')
# Out:
# /home/rzw/.local/lib/python3.8/site-packages/sklearn/base.py:488: FutureWarning: The feature names should match those that were passed during fit. Starting version 1.2, an error will be raised.
# Feature names unseen at fit time:
# - 0
# - 1
# - 10
# - 100
# - 101
# - ...
# Feature names seen at fit time, yet now missing:
# - band1
# - band10
# - band100
# - band101
# - band102
# - ...
#
#   warnings.warn(message, FutureWarning)
# /home/rzw/.local/lib/python3.8/site-packages/sklearn/base.py:488: FutureWarning: The feature names should match those that were passed during fit. Starting version 1.2, an error will be raised.
# Feature names unseen at fit time:
# - 10
# - 11
# - 12
# - 13
# - 14
# - ...
# Feature names seen at fit time, yet now missing:
# - band10
# - band11
# - band12
# - band13
# - band14
# - ...
#
#   warnings.warn(message, FutureWarning)
# /home/rzw/.local/lib/python3.8/site-packages/sklearn/base.py:488: FutureWarning: The feature names should match those that were passed during fit. Starting version 1.2, an error will be raised.
# Feature names unseen at fit time:
# - 62
# - 63
# - 64
# - 65
# - 66
# - ...
# Feature names seen at fit time, yet now missing:
# - band63
# - band64
# - band65
# - band66
# - band67
# - ...
#
#   warnings.warn(message, FutureWarning)
# /home/rzw/.local/lib/python3.8/site-packages/sklearn/base.py:488: FutureWarning: The feature names should match those that were passed during fit. Starting version 1.2, an error will be raised.
# Feature names unseen at fit time:
# - 100
# - 101
# - 102
# - 103
# - 104
# - ...
# Feature names seen at fit time, yet now missing:
# - band100
# - band101
# - band102
# - band103
# - band104
# - ...
#
#   warnings.warn(message, FutureWarning)
# /home/rzw/.local/lib/python3.8/site-packages/sklearn/base.py:488: FutureWarning: The feature names should match those that were passed during fit. Starting version 1.2, an error will be raised.
# Feature names unseen at fit time:
# - 186
# - 187
# - 188
# - 189
# - 190
# - ...
# Feature names seen at fit time, yet now missing:
# - band187
# - band188
# - band189
# - band190
# - band191
# - ...
#
#   warnings.warn(message, FutureWarning)
# /home/rzw/.local/lib/python3.8/site-packages/sklearn/base.py:488: FutureWarning: The feature names should match those that were passed during fit. Starting version 1.2, an error will be raised.
# Feature names unseen at fit time:
# - 0
# - 1
# - 10
# - 100
# - 101
# - ...
# Feature names seen at fit time, yet now missing:
# - band1
# - band10
# - band100
# - band101
# - band102
# - ...
#
#   warnings.warn(message, FutureWarning)
# /home/rzw/.local/lib/python3.8/site-packages/sklearn/base.py:488: FutureWarning: The feature names should match those that were passed during fit. Starting version 1.2, an error will be raised.
# Feature names unseen at fit time:
# - 10
# - 11
# - 12
# - 13
# - 14
# - ...
# Feature names seen at fit time, yet now missing:
# - band10
# - band11
# - band12
# - band13
# - band14
# - ...
#
#   warnings.warn(message, FutureWarning)
# /home/rzw/.local/lib/python3.8/site-packages/sklearn/base.py:488: FutureWarning: The feature names should match those that were passed during fit. Starting version 1.2, an error will be raised.
# Feature names unseen at fit time:
# - 62
# - 63
# - 64
# - 65
# - 66
# - ...
# Feature names seen at fit time, yet now missing:
# - band63
# - band64
# - band65
# - band66
# - band67
# - ...
#
#   warnings.warn(message, FutureWarning)
# /home/rzw/.local/lib/python3.8/site-packages/sklearn/base.py:488: FutureWarning: The feature names should match those that were passed during fit. Starting version 1.2, an error will be raised.
# Feature names unseen at fit time:
# - 100
# - 101
# - 102
# - 103
# - 104
# - ...
# Feature names seen at fit time, yet now missing:
# - band100
# - band101
# - band102
# - band103
# - band104
# - ...
#
#   warnings.warn(message, FutureWarning)
# /home/rzw/.local/lib/python3.8/site-packages/sklearn/base.py:488: FutureWarning: The feature names should match those that were passed during fit. Starting version 1.2, an error will be raised.
# Feature names unseen at fit time:
# - 186
# - 187
# - 188
# - 189
# - 190
# - ...
# Feature names seen at fit time, yet now missing:
# - band187
# - band188
# - band189
# - band190
# - band191
# - ...
#
#   warnings.warn(message, FutureWarning)
# /home/rzw/.local/lib/python3.8/site-packages/sklearn/base.py:488: FutureWarning: The feature names should match those that were passed during fit. Starting version 1.2, an error will be raised.
# Feature names unseen at fit time:
# - 0
# - 1
# - 10
# - 100
# - 101
# - ...
# Feature names seen at fit time, yet now missing:
# - band1
# - band10
# - band100
# - band101
# - band102
# - ...
#
#   warnings.warn(message, FutureWarning)
# /home/rzw/.local/lib/python3.8/site-packages/sklearn/base.py:488: FutureWarning: The feature names should match those that were passed during fit. Starting version 1.2, an error will be raised.
# Feature names unseen at fit time:
# - 10
# - 11
# - 12
# - 13
# - 14
# - ...
# Feature names seen at fit time, yet now missing:
# - band10
# - band11
# - band12
# - band13
# - band14
# - ...
#
#   warnings.warn(message, FutureWarning)
# /home/rzw/.local/lib/python3.8/site-packages/sklearn/base.py:488: FutureWarning: The feature names should match those that were passed during fit. Starting version 1.2, an error will be raised.
# Feature names unseen at fit time:
# - 62
# - 63
# - 64
# - 65
# - 66
# - ...
# Feature names seen at fit time, yet now missing:
# - band63
# - band64
# - band65
# - band66
# - band67
# - ...
#
#   warnings.warn(message, FutureWarning)
# /home/rzw/.local/lib/python3.8/site-packages/sklearn/base.py:488: FutureWarning: The feature names should match those that were passed during fit. Starting version 1.2, an error will be raised.
# Feature names unseen at fit time:
# - 100
# - 101
# - 102
# - 103
# - 104
# - ...
# Feature names seen at fit time, yet now missing:
# - band100
# - band101
# - band102
# - band103
# - band104
# - ...
#
#   warnings.warn(message, FutureWarning)
# /home/rzw/.local/lib/python3.8/site-packages/sklearn/base.py:488: FutureWarning: The feature names should match those that were passed during fit. Starting version 1.2, an error will be raised.
# Feature names unseen at fit time:
# - 186
# - 187
# - 188
# - 189
# - 190
# - ...
# Feature names seen at fit time, yet now missing:
# - band187
# - band188
# - band189
# - band190
# - band191
# - ...
#
#   warnings.warn(message, FutureWarning)
# /mnt/c/Users/rache/OneDrive - The University of Nottingham/MRes/Flow_Country_HSI_and_PSM/python_notebooks/hyperspectral_machine_learning/random_forest.py:40: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
#   row['model_result'].to_file(f"{output_directory}/{site_name}-{row['data_transformation']}-{row['spectrum']}-{test_size}-{max_depth}-{cv}-{formatted_date}.shp")
# /mnt/c/Users/rache/OneDrive - The University of Nottingham/MRes/Flow_Country_HSI_and_PSM/python_notebooks/hyperspectral_machine_learning/random_forest.py:40: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
#   row['model_result'].to_file(f"{output_directory}/{site_name}-{row['data_transformation']}-{row['spectrum']}-{test_size}-{max_depth}-{cv}-{formatted_date}.shp")
# /mnt/c/Users/rache/OneDrive - The University of Nottingham/MRes/Flow_Country_HSI_and_PSM/python_notebooks/hyperspectral_machine_learning/random_forest.py:40: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
#   row['model_result'].to_file(f"{output_directory}/{site_name}-{row['data_transformation']}-{row['spectrum']}-{test_size}-{max_depth}-{cv}-{formatted_date}.shp")
# /mnt/c/Users/rache/OneDrive - The University of Nottingham/MRes/Flow_Country_HSI_and_PSM/python_notebooks/hyperspectral_machine_learning/random_forest.py:40: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
#   row['model_result'].to_file(f"{output_directory}/{site_name}-{row['data_transformation']}-{row['spectrum']}-{test_size}-{max_depth}-{cv}-{formatted_date}.shp")
# /mnt/c/Users/rache/OneDrive - The University of Nottingham/MRes/Flow_Country_HSI_and_PSM/python_notebooks/hyperspectral_machine_learning/random_forest.py:40: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
#   row['model_result'].to_file(f"{output_directory}/{site_name}-{row['data_transformation']}-{row['spectrum']}-{test_size}-{max_depth}-{cv}-{formatted_date}.shp")
#                                          model_result spectrum  \
# 0          POINTID                        geometry...     full
# 1          POINTID                        geometry...      VIS
# 2          POINTID                        geometry...       RE
# 3          POINTID                        geometry...      NIR
# 4          POINTID                        geometry...     SWIR
# 5                                geometry   clf_pr...     full
# 6                                geometry   clf_pr...      VIS
# 7                                geometry   clf_pr...       RE
# 8                                geometry   clf_pr...      NIR
# 9                                geometry   clf_pr...     SWIR
# 10                               geometry   clf_pr...     full
# 11                               geometry   clf_pr...      VIS
# 12                               geometry   clf_pr...       RE
# 13                               geometry   clf_pr...      NIR
# 14                               geometry   clf_pr...     SWIR
# 15                               geometry   clf_pr...     full
# 16                               geometry   clf_pr...      VIS
# 17                               geometry   clf_pr...       RE
# 18                               geometry   clf_pr...      NIR
# 19                               geometry   clf_pr...     SWIR
#
#    data_transformation  accuracy_mean  accuracy_standard_deviation
# 0             original       0.653248                     0.017295
# 1             original       0.592429                     0.044806
# 2             original       0.569290                     0.022972
# 3             original       0.586607                     0.024360
# 4             original       0.595327                     0.015924
# 5     first derivative       0.699550                     0.032173
# 6     first derivative       0.552049                     0.009509
# 7     first derivative       0.514468                     0.011424
# 8     first derivative       0.595527                     0.041100
# 9     first derivative       0.604023                     0.015297
# 10   second derivative       0.641754                     0.051244
# 11   second derivative       0.572239                     0.025136
# 12   second derivative       0.563493                     0.026317
# 13   second derivative       0.580885                     0.012150
# 14   second derivative       0.543328                     0.035993
# 15   continuum removal       0.600925                     0.056757
# 16   continuum removal       0.476787                     0.042035
# 17   continuum removal       0.531709                     0.026927
# 18   continuum removal       0.520065                     0.042045
# 19   continuum removal       0.531534                     0.064622

# %%
hml.random_forest.random_forest_csv_and_shape_file_outputs('erosion_updated', data_transformations, test_size=0.25, max_depth=4, output_directory='outputs')
# Out:
# /home/rzw/.local/lib/python3.8/site-packages/sklearn/base.py:488: FutureWarning: The feature names should match those that were passed during fit. Starting version 1.2, an error will be raised.
# Feature names unseen at fit time:
# - 0
# - 1
# - 10
# - 100
# - 101
# - ...
# Feature names seen at fit time, yet now missing:
# - band1
# - band10
# - band100
# - band101
# - band102
# - ...
#
#   warnings.warn(message, FutureWarning)
# /home/rzw/.local/lib/python3.8/site-packages/sklearn/base.py:488: FutureWarning: The feature names should match those that were passed during fit. Starting version 1.2, an error will be raised.
# Feature names unseen at fit time:
# - 10
# - 11
# - 12
# - 13
# - 14
# - ...
# Feature names seen at fit time, yet now missing:
# - band10
# - band11
# - band12
# - band13
# - band14
# - ...
#
#   warnings.warn(message, FutureWarning)
# /home/rzw/.local/lib/python3.8/site-packages/sklearn/base.py:488: FutureWarning: The feature names should match those that were passed during fit. Starting version 1.2, an error will be raised.
# Feature names unseen at fit time:
# - 62
# - 63
# - 64
# - 65
# - 66
# - ...
# Feature names seen at fit time, yet now missing:
# - band63
# - band64
# - band65
# - band66
# - band67
# - ...
#
#   warnings.warn(message, FutureWarning)
# /home/rzw/.local/lib/python3.8/site-packages/sklearn/base.py:488: FutureWarning: The feature names should match those that were passed during fit. Starting version 1.2, an error will be raised.
# Feature names unseen at fit time:
# - 100
# - 101
# - 102
# - 103
# - 104
# - ...
# Feature names seen at fit time, yet now missing:
# - band100
# - band101
# - band102
# - band103
# - band104
# - ...
#
#   warnings.warn(message, FutureWarning)
# /home/rzw/.local/lib/python3.8/site-packages/sklearn/base.py:488: FutureWarning: The feature names should match those that were passed during fit. Starting version 1.2, an error will be raised.
# Feature names unseen at fit time:
# - 186
# - 187
# - 188
# - 189
# - 190
# - ...
# Feature names seen at fit time, yet now missing:
# - band187
# - band188
# - band189
# - band190
# - band191
# - ...
#
#   warnings.warn(message, FutureWarning)
# /home/rzw/.local/lib/python3.8/site-packages/sklearn/base.py:488: FutureWarning: The feature names should match those that were passed during fit. Starting version 1.2, an error will be raised.
# Feature names unseen at fit time:
# - 0
# - 1
# - 10
# - 100
# - 101
# - ...
# Feature names seen at fit time, yet now missing:
# - band1
# - band10
# - band100
# - band101
# - band102
# - ...
#
#   warnings.warn(message, FutureWarning)
# /home/rzw/.local/lib/python3.8/site-packages/sklearn/base.py:488: FutureWarning: The feature names should match those that were passed during fit. Starting version 1.2, an error will be raised.
# Feature names unseen at fit time:
# - 10
# - 11
# - 12
# - 13
# - 14
# - ...
# Feature names seen at fit time, yet now missing:
# - band10
# - band11
# - band12
# - band13
# - band14
# - ...
#
#   warnings.warn(message, FutureWarning)
# /home/rzw/.local/lib/python3.8/site-packages/sklearn/base.py:488: FutureWarning: The feature names should match those that were passed during fit. Starting version 1.2, an error will be raised.
# Feature names unseen at fit time:
# - 62
# - 63
# - 64
# - 65
# - 66
# - ...
# Feature names seen at fit time, yet now missing:
# - band63
# - band64
# - band65
# - band66
# - band67
# - ...
#
#   warnings.warn(message, FutureWarning)
# /home/rzw/.local/lib/python3.8/site-packages/sklearn/base.py:488: FutureWarning: The feature names should match those that were passed during fit. Starting version 1.2, an error will be raised.
# Feature names unseen at fit time:
# - 100
# - 101
# - 102
# - 103
# - 104
# - ...
# Feature names seen at fit time, yet now missing:
# - band100
# - band101
# - band102
# - band103
# - band104
# - ...
#
#   warnings.warn(message, FutureWarning)
# /home/rzw/.local/lib/python3.8/site-packages/sklearn/base.py:488: FutureWarning: The feature names should match those that were passed during fit. Starting version 1.2, an error will be raised.
# Feature names unseen at fit time:
# - 186
# - 187
# - 188
# - 189
# - 190
# - ...
# Feature names seen at fit time, yet now missing:
# - band187
# - band188
# - band189
# - band190
# - band191
# - ...
#
#   warnings.warn(message, FutureWarning)
# /home/rzw/.local/lib/python3.8/site-packages/sklearn/base.py:488: FutureWarning: The feature names should match those that were passed during fit. Starting version 1.2, an error will be raised.
# Feature names unseen at fit time:
# - 0
# - 1
# - 10
# - 100
# - 101
# - ...
# Feature names seen at fit time, yet now missing:
# - band1
# - band10
# - band100
# - band101
# - band102
# - ...
#
#   warnings.warn(message, FutureWarning)
# /home/rzw/.local/lib/python3.8/site-packages/sklearn/base.py:488: FutureWarning: The feature names should match those that were passed during fit. Starting version 1.2, an error will be raised.
# Feature names unseen at fit time:
# - 10
# - 11
# - 12
# - 13
# - 14
# - ...
# Feature names seen at fit time, yet now missing:
# - band10
# - band11
# - band12
# - band13
# - band14
# - ...
#
#   warnings.warn(message, FutureWarning)
# /home/rzw/.local/lib/python3.8/site-packages/sklearn/base.py:488: FutureWarning: The feature names should match those that were passed during fit. Starting version 1.2, an error will be raised.
# Feature names unseen at fit time:
# - 62
# - 63
# - 64
# - 65
# - 66
# - ...
# Feature names seen at fit time, yet now missing:
# - band63
# - band64
# - band65
# - band66
# - band67
# - ...
#
#   warnings.warn(message, FutureWarning)
# /home/rzw/.local/lib/python3.8/site-packages/sklearn/base.py:488: FutureWarning: The feature names should match those that were passed during fit. Starting version 1.2, an error will be raised.
# Feature names unseen at fit time:
# - 100
# - 101
# - 102
# - 103
# - 104
# - ...
# Feature names seen at fit time, yet now missing:
# - band100
# - band101
# - band102
# - band103
# - band104
# - ...
#
#   warnings.warn(message, FutureWarning)
# /home/rzw/.local/lib/python3.8/site-packages/sklearn/base.py:488: FutureWarning: The feature names should match those that were passed during fit. Starting version 1.2, an error will be raised.
# Feature names unseen at fit time:
# - 186
# - 187
# - 188
# - 189
# - 190
# - ...
# Feature names seen at fit time, yet now missing:
# - band187
# - band188
# - band189
# - band190
# - band191
# - ...
#
#   warnings.warn(message, FutureWarning)
# /mnt/c/Users/rache/OneDrive - The University of Nottingham/MRes/Flow_Country_HSI_and_PSM/python_notebooks/hyperspectral_machine_learning/random_forest.py:40: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
#   row['model_result'].to_file(f"{output_directory}/{site_name}-{row['data_transformation']}-{row['spectrum']}-{test_size}-{max_depth}-{cv}-{formatted_date}.shp")
# /mnt/c/Users/rache/OneDrive - The University of Nottingham/MRes/Flow_Country_HSI_and_PSM/python_notebooks/hyperspectral_machine_learning/random_forest.py:40: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
#   row['model_result'].to_file(f"{output_directory}/{site_name}-{row['data_transformation']}-{row['spectrum']}-{test_size}-{max_depth}-{cv}-{formatted_date}.shp")
# /mnt/c/Users/rache/OneDrive - The University of Nottingham/MRes/Flow_Country_HSI_and_PSM/python_notebooks/hyperspectral_machine_learning/random_forest.py:40: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
#   row['model_result'].to_file(f"{output_directory}/{site_name}-{row['data_transformation']}-{row['spectrum']}-{test_size}-{max_depth}-{cv}-{formatted_date}.shp")
# /mnt/c/Users/rache/OneDrive - The University of Nottingham/MRes/Flow_Country_HSI_and_PSM/python_notebooks/hyperspectral_machine_learning/random_forest.py:40: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
#   row['model_result'].to_file(f"{output_directory}/{site_name}-{row['data_transformation']}-{row['spectrum']}-{test_size}-{max_depth}-{cv}-{formatted_date}.shp")
# /mnt/c/Users/rache/OneDrive - The University of Nottingham/MRes/Flow_Country_HSI_and_PSM/python_notebooks/hyperspectral_machine_learning/random_forest.py:40: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
#   row['model_result'].to_file(f"{output_directory}/{site_name}-{row['data_transformation']}-{row['spectrum']}-{test_size}-{max_depth}-{cv}-{formatted_date}.shp")
#                                          model_result spectrum  \
# 0          POINTID                        geometry...     full
# 1          POINTID                        geometry...      VIS
# 2          POINTID                        geometry...       RE
# 3          POINTID                        geometry...      NIR
# 4          POINTID                        geometry...     SWIR
# 5                                geometry   clf_pr...     full
# 6                                geometry   clf_pr...      VIS
# 7                                geometry   clf_pr...       RE
# 8                                geometry   clf_pr...      NIR
# 9                                geometry   clf_pr...     SWIR
# 10                               geometry   clf_pr...     full
# 11                               geometry   clf_pr...      VIS
# 12                               geometry   clf_pr...       RE
# 13                               geometry   clf_pr...      NIR
# 14                               geometry   clf_pr...     SWIR
# 15                               geometry clf_pred...     full
# 16                               geometry   clf_pr...      VIS
# 17                               geometry   clf_pr...       RE
# 18                               geometry   clf_pr...      NIR
# 19                               geometry   clf_pr...     SWIR
#
#    data_transformation  accuracy_mean  accuracy_standard_deviation
# 0             original       0.596435                     0.044839
# 1             original       0.568943                     0.006203
# 2             original       0.544817                     0.058965
# 3             original       0.499785                     0.063899
# 4             original       0.520511                     0.037556
# 5     first derivative       0.617053                     0.054063
# 6     first derivative       0.517039                     0.048589
# 7     first derivative       0.458512                     0.023764
# 8     first derivative       0.606744                     0.035527
# 9     first derivative       0.555126                     0.010406
# 10   second derivative       0.627577                     0.008613
# 11   second derivative       0.579288                     0.006165
# 12   second derivative       0.568979                     0.017064
# 13   second derivative       0.606744                     0.059410
# 14   second derivative       0.548182                     0.058031
# 15   continuum removal       0.610503                     0.033426
# 16   continuum removal       0.458477                     0.029862
# 17   continuum removal       0.475838                     0.006545
# 18   continuum removal       0.569086                     0.032529
# 19   continuum removal       0.531322                     0.062523

# %%
hml.random_forest.random_forest_csv_and_shape_file_outputs('erosion_updated', data_transformations, test_size=0.3, max_depth=5, output_directory='outputs', cv=5)
# Out:
# /home/rzw/.local/lib/python3.8/site-packages/sklearn/base.py:488: FutureWarning: The feature names should match those that were passed during fit. Starting version 1.2, an error will be raised.
# Feature names unseen at fit time:
# - 0
# - 1
# - 10
# - 100
# - 101
# - ...
# Feature names seen at fit time, yet now missing:
# - band1
# - band10
# - band100
# - band101
# - band102
# - ...
#
#   warnings.warn(message, FutureWarning)
# /home/rzw/.local/lib/python3.8/site-packages/sklearn/base.py:488: FutureWarning: The feature names should match those that were passed during fit. Starting version 1.2, an error will be raised.
# Feature names unseen at fit time:
# - 10
# - 11
# - 12
# - 13
# - 14
# - ...
# Feature names seen at fit time, yet now missing:
# - band10
# - band11
# - band12
# - band13
# - band14
# - ...
#
#   warnings.warn(message, FutureWarning)
# /home/rzw/.local/lib/python3.8/site-packages/sklearn/base.py:488: FutureWarning: The feature names should match those that were passed during fit. Starting version 1.2, an error will be raised.
# Feature names unseen at fit time:
# - 62
# - 63
# - 64
# - 65
# - 66
# - ...
# Feature names seen at fit time, yet now missing:
# - band63
# - band64
# - band65
# - band66
# - band67
# - ...
#
#   warnings.warn(message, FutureWarning)
# /home/rzw/.local/lib/python3.8/site-packages/sklearn/base.py:488: FutureWarning: The feature names should match those that were passed during fit. Starting version 1.2, an error will be raised.
# Feature names unseen at fit time:
# - 100
# - 101
# - 102
# - 103
# - 104
# - ...
# Feature names seen at fit time, yet now missing:
# - band100
# - band101
# - band102
# - band103
# - band104
# - ...
#
#   warnings.warn(message, FutureWarning)
# /home/rzw/.local/lib/python3.8/site-packages/sklearn/base.py:488: FutureWarning: The feature names should match those that were passed during fit. Starting version 1.2, an error will be raised.
# Feature names unseen at fit time:
# - 186
# - 187
# - 188
# - 189
# - 190
# - ...
# Feature names seen at fit time, yet now missing:
# - band187
# - band188
# - band189
# - band190
# - band191
# - ...
#
#   warnings.warn(message, FutureWarning)
# /home/rzw/.local/lib/python3.8/site-packages/sklearn/base.py:488: FutureWarning: The feature names should match those that were passed during fit. Starting version 1.2, an error will be raised.
# Feature names unseen at fit time:
# - 0
# - 1
# - 10
# - 100
# - 101
# - ...
# Feature names seen at fit time, yet now missing:
# - band1
# - band10
# - band100
# - band101
# - band102
# - ...
#
#   warnings.warn(message, FutureWarning)
# /home/rzw/.local/lib/python3.8/site-packages/sklearn/base.py:488: FutureWarning: The feature names should match those that were passed during fit. Starting version 1.2, an error will be raised.
# Feature names unseen at fit time:
# - 10
# - 11
# - 12
# - 13
# - 14
# - ...
# Feature names seen at fit time, yet now missing:
# - band10
# - band11
# - band12
# - band13
# - band14
# - ...
#
#   warnings.warn(message, FutureWarning)
# /home/rzw/.local/lib/python3.8/site-packages/sklearn/base.py:488: FutureWarning: The feature names should match those that were passed during fit. Starting version 1.2, an error will be raised.
# Feature names unseen at fit time:
# - 62
# - 63
# - 64
# - 65
# - 66
# - ...
# Feature names seen at fit time, yet now missing:
# - band63
# - band64
# - band65
# - band66
# - band67
# - ...
#
#   warnings.warn(message, FutureWarning)
# /home/rzw/.local/lib/python3.8/site-packages/sklearn/base.py:488: FutureWarning: The feature names should match those that were passed during fit. Starting version 1.2, an error will be raised.
# Feature names unseen at fit time:
# - 100
# - 101
# - 102
# - 103
# - 104
# - ...
# Feature names seen at fit time, yet now missing:
# - band100
# - band101
# - band102
# - band103
# - band104
# - ...
#
#   warnings.warn(message, FutureWarning)
# /home/rzw/.local/lib/python3.8/site-packages/sklearn/base.py:488: FutureWarning: The feature names should match those that were passed during fit. Starting version 1.2, an error will be raised.
# Feature names unseen at fit time:
# - 186
# - 187
# - 188
# - 189
# - 190
# - ...
# Feature names seen at fit time, yet now missing:
# - band187
# - band188
# - band189
# - band190
# - band191
# - ...
#
#   warnings.warn(message, FutureWarning)
# /home/rzw/.local/lib/python3.8/site-packages/sklearn/base.py:488: FutureWarning: The feature names should match those that were passed during fit. Starting version 1.2, an error will be raised.
# Feature names unseen at fit time:
# - 0
# - 1
# - 10
# - 100
# - 101
# - ...
# Feature names seen at fit time, yet now missing:
# - band1
# - band10
# - band100
# - band101
# - band102
# - ...
#
#   warnings.warn(message, FutureWarning)
# /home/rzw/.local/lib/python3.8/site-packages/sklearn/base.py:488: FutureWarning: The feature names should match those that were passed during fit. Starting version 1.2, an error will be raised.
# Feature names unseen at fit time:
# - 10
# - 11
# - 12
# - 13
# - 14
# - ...
# Feature names seen at fit time, yet now missing:
# - band10
# - band11
# - band12
# - band13
# - band14
# - ...
#
#   warnings.warn(message, FutureWarning)
# /home/rzw/.local/lib/python3.8/site-packages/sklearn/base.py:488: FutureWarning: The feature names should match those that were passed during fit. Starting version 1.2, an error will be raised.
# Feature names unseen at fit time:
# - 62
# - 63
# - 64
# - 65
# - 66
# - ...
# Feature names seen at fit time, yet now missing:
# - band63
# - band64
# - band65
# - band66
# - band67
# - ...
#
#   warnings.warn(message, FutureWarning)
# /home/rzw/.local/lib/python3.8/site-packages/sklearn/base.py:488: FutureWarning: The feature names should match those that were passed during fit. Starting version 1.2, an error will be raised.
# Feature names unseen at fit time:
# - 100
# - 101
# - 102
# - 103
# - 104
# - ...
# Feature names seen at fit time, yet now missing:
# - band100
# - band101
# - band102
# - band103
# - band104
# - ...
#
#   warnings.warn(message, FutureWarning)
# /home/rzw/.local/lib/python3.8/site-packages/sklearn/base.py:488: FutureWarning: The feature names should match those that were passed during fit. Starting version 1.2, an error will be raised.
# Feature names unseen at fit time:
# - 186
# - 187
# - 188
# - 189
# - 190
# - ...
# Feature names seen at fit time, yet now missing:
# - band187
# - band188
# - band189
# - band190
# - band191
# - ...
#
#   warnings.warn(message, FutureWarning)
# /mnt/c/Users/rache/OneDrive - The University of Nottingham/MRes/Flow_Country_HSI_and_PSM/python_notebooks/hyperspectral_machine_learning/random_forest.py:40: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
#   row['model_result'].to_file(f"{output_directory}/{site_name}-{row['data_transformation']}-{row['spectrum']}-{test_size}-{max_depth}-{cv}-{formatted_date}.shp")
# /mnt/c/Users/rache/OneDrive - The University of Nottingham/MRes/Flow_Country_HSI_and_PSM/python_notebooks/hyperspectral_machine_learning/random_forest.py:40: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
#   row['model_result'].to_file(f"{output_directory}/{site_name}-{row['data_transformation']}-{row['spectrum']}-{test_size}-{max_depth}-{cv}-{formatted_date}.shp")
# /mnt/c/Users/rache/OneDrive - The University of Nottingham/MRes/Flow_Country_HSI_and_PSM/python_notebooks/hyperspectral_machine_learning/random_forest.py:40: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
#   row['model_result'].to_file(f"{output_directory}/{site_name}-{row['data_transformation']}-{row['spectrum']}-{test_size}-{max_depth}-{cv}-{formatted_date}.shp")
# /mnt/c/Users/rache/OneDrive - The University of Nottingham/MRes/Flow_Country_HSI_and_PSM/python_notebooks/hyperspectral_machine_learning/random_forest.py:40: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
#   row['model_result'].to_file(f"{output_directory}/{site_name}-{row['data_transformation']}-{row['spectrum']}-{test_size}-{max_depth}-{cv}-{formatted_date}.shp")
# /mnt/c/Users/rache/OneDrive - The University of Nottingham/MRes/Flow_Country_HSI_and_PSM/python_notebooks/hyperspectral_machine_learning/random_forest.py:40: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
#   row['model_result'].to_file(f"{output_directory}/{site_name}-{row['data_transformation']}-{row['spectrum']}-{test_size}-{max_depth}-{cv}-{formatted_date}.shp")
#                                          model_result spectrum  \
# 0          POINTID                        geometry...     full
# 1          POINTID                        geometry...      VIS
# 2          POINTID                        geometry...       RE
# 3          POINTID                        geometry...      NIR
# 4          POINTID                        geometry...     SWIR
# 5                                geometry   clf_pr...     full
# 6                                geometry   clf_pr...      VIS
# 7                                geometry   clf_pr...       RE
# 8                                geometry   clf_pr...      NIR
# 9                                geometry   clf_pr...     SWIR
# 10                               geometry   clf_pr...     full
# 11                               geometry   clf_pr...      VIS
# 12                               geometry   clf_pr...       RE
# 13                               geometry   clf_pr...      NIR
# 14                               geometry   clf_pr...     SWIR
# 15                               geometry   clf_pr...     full
# 16                               geometry   clf_pr...      VIS
# 17                               geometry   clf_pr...       RE
# 18                               geometry   clf_pr...      NIR
# 19                               geometry clf_pred...     SWIR
#
#    data_transformation  accuracy_mean  accuracy_standard_deviation
# 0             original       0.702236                     0.060150
# 1             original       0.632795                     0.052421
# 2             original       0.609689                     0.057297
# 3             original       0.583810                     0.059675
# 4             original       0.647329                     0.020706
# 5     first derivative       0.731263                     0.074596
# 6     first derivative       0.566501                     0.042635
# 7     first derivative       0.531677                     0.049954
# 8     first derivative       0.667453                     0.056589
# 9     first derivative       0.656025                     0.046473
# 10   second derivative       0.687867                     0.078053
# 11   second derivative       0.656149                     0.060550
# 12   second derivative       0.621408                     0.084582
# 13   second derivative       0.618634                     0.077305
# 14   second derivative       0.644679                     0.098229
# 15   continuum removal       0.661822                     0.027152
# 16   continuum removal       0.540455                     0.051356
# 17   continuum removal       0.534658                     0.011503
# 18   continuum removal       0.581035                     0.028565
# 19   continuum removal       0.563602                     0.024465

# %%
hml.random_forest.random_forest_csv_and_shape_file_outputs('erosion_updated', data_transformations, test_size=0.25, max_depth=5, output_directory='outputs', cv=5)
# Out:
# /home/rzw/.local/lib/python3.8/site-packages/sklearn/base.py:488: FutureWarning: The feature names should match those that were passed during fit. Starting version 1.2, an error will be raised.
# Feature names unseen at fit time:
# - 0
# - 1
# - 10
# - 100
# - 101
# - ...
# Feature names seen at fit time, yet now missing:
# - band1
# - band10
# - band100
# - band101
# - band102
# - ...
#
#   warnings.warn(message, FutureWarning)
# /home/rzw/.local/lib/python3.8/site-packages/sklearn/base.py:488: FutureWarning: The feature names should match those that were passed during fit. Starting version 1.2, an error will be raised.
# Feature names unseen at fit time:
# - 10
# - 11
# - 12
# - 13
# - 14
# - ...
# Feature names seen at fit time, yet now missing:
# - band10
# - band11
# - band12
# - band13
# - band14
# - ...
#
#   warnings.warn(message, FutureWarning)
# /home/rzw/.local/lib/python3.8/site-packages/sklearn/base.py:488: FutureWarning: The feature names should match those that were passed during fit. Starting version 1.2, an error will be raised.
# Feature names unseen at fit time:
# - 62
# - 63
# - 64
# - 65
# - 66
# - ...
# Feature names seen at fit time, yet now missing:
# - band63
# - band64
# - band65
# - band66
# - band67
# - ...
#
#   warnings.warn(message, FutureWarning)
# /home/rzw/.local/lib/python3.8/site-packages/sklearn/base.py:488: FutureWarning: The feature names should match those that were passed during fit. Starting version 1.2, an error will be raised.
# Feature names unseen at fit time:
# - 100
# - 101
# - 102
# - 103
# - 104
# - ...
# Feature names seen at fit time, yet now missing:
# - band100
# - band101
# - band102
# - band103
# - band104
# - ...
#
#   warnings.warn(message, FutureWarning)
# /home/rzw/.local/lib/python3.8/site-packages/sklearn/base.py:488: FutureWarning: The feature names should match those that were passed during fit. Starting version 1.2, an error will be raised.
# Feature names unseen at fit time:
# - 186
# - 187
# - 188
# - 189
# - 190
# - ...
# Feature names seen at fit time, yet now missing:
# - band187
# - band188
# - band189
# - band190
# - band191
# - ...
#
#   warnings.warn(message, FutureWarning)
# /home/rzw/.local/lib/python3.8/site-packages/sklearn/base.py:488: FutureWarning: The feature names should match those that were passed during fit. Starting version 1.2, an error will be raised.
# Feature names unseen at fit time:
# - 0
# - 1
# - 10
# - 100
# - 101
# - ...
# Feature names seen at fit time, yet now missing:
# - band1
# - band10
# - band100
# - band101
# - band102
# - ...
#
#   warnings.warn(message, FutureWarning)
# /home/rzw/.local/lib/python3.8/site-packages/sklearn/base.py:488: FutureWarning: The feature names should match those that were passed during fit. Starting version 1.2, an error will be raised.
# Feature names unseen at fit time:
# - 10
# - 11
# - 12
# - 13
# - 14
# - ...
# Feature names seen at fit time, yet now missing:
# - band10
# - band11
# - band12
# - band13
# - band14
# - ...
#
#   warnings.warn(message, FutureWarning)
# /home/rzw/.local/lib/python3.8/site-packages/sklearn/base.py:488: FutureWarning: The feature names should match those that were passed during fit. Starting version 1.2, an error will be raised.
# Feature names unseen at fit time:
# - 62
# - 63
# - 64
# - 65
# - 66
# - ...
# Feature names seen at fit time, yet now missing:
# - band63
# - band64
# - band65
# - band66
# - band67
# - ...
#
#   warnings.warn(message, FutureWarning)
# /home/rzw/.local/lib/python3.8/site-packages/sklearn/base.py:488: FutureWarning: The feature names should match those that were passed during fit. Starting version 1.2, an error will be raised.
# Feature names unseen at fit time:
# - 100
# - 101
# - 102
# - 103
# - 104
# - ...
# Feature names seen at fit time, yet now missing:
# - band100
# - band101
# - band102
# - band103
# - band104
# - ...
#
#   warnings.warn(message, FutureWarning)
# /home/rzw/.local/lib/python3.8/site-packages/sklearn/base.py:488: FutureWarning: The feature names should match those that were passed during fit. Starting version 1.2, an error will be raised.
# Feature names unseen at fit time:
# - 186
# - 187
# - 188
# - 189
# - 190
# - ...
# Feature names seen at fit time, yet now missing:
# - band187
# - band188
# - band189
# - band190
# - band191
# - ...
#
#   warnings.warn(message, FutureWarning)
# /home/rzw/.local/lib/python3.8/site-packages/sklearn/base.py:488: FutureWarning: The feature names should match those that were passed during fit. Starting version 1.2, an error will be raised.
# Feature names unseen at fit time:
# - 0
# - 1
# - 10
# - 100
# - 101
# - ...
# Feature names seen at fit time, yet now missing:
# - band1
# - band10
# - band100
# - band101
# - band102
# - ...
#
#   warnings.warn(message, FutureWarning)
# /home/rzw/.local/lib/python3.8/site-packages/sklearn/base.py:488: FutureWarning: The feature names should match those that were passed during fit. Starting version 1.2, an error will be raised.
# Feature names unseen at fit time:
# - 10
# - 11
# - 12
# - 13
# - 14
# - ...
# Feature names seen at fit time, yet now missing:
# - band10
# - band11
# - band12
# - band13
# - band14
# - ...
#
#   warnings.warn(message, FutureWarning)
# /home/rzw/.local/lib/python3.8/site-packages/sklearn/base.py:488: FutureWarning: The feature names should match those that were passed during fit. Starting version 1.2, an error will be raised.
# Feature names unseen at fit time:
# - 62
# - 63
# - 64
# - 65
# - 66
# - ...
# Feature names seen at fit time, yet now missing:
# - band63
# - band64
# - band65
# - band66
# - band67
# - ...
#
#   warnings.warn(message, FutureWarning)
# /home/rzw/.local/lib/python3.8/site-packages/sklearn/base.py:488: FutureWarning: The feature names should match those that were passed during fit. Starting version 1.2, an error will be raised.
# Feature names unseen at fit time:
# - 100
# - 101
# - 102
# - 103
# - 104
# - ...
# Feature names seen at fit time, yet now missing:
# - band100
# - band101
# - band102
# - band103
# - band104
# - ...
#
#   warnings.warn(message, FutureWarning)
# /home/rzw/.local/lib/python3.8/site-packages/sklearn/base.py:488: FutureWarning: The feature names should match those that were passed during fit. Starting version 1.2, an error will be raised.
# Feature names unseen at fit time:
# - 186
# - 187
# - 188
# - 189
# - 190
# - ...
# Feature names seen at fit time, yet now missing:
# - band187
# - band188
# - band189
# - band190
# - band191
# - ...
#
#   warnings.warn(message, FutureWarning)
# /mnt/c/Users/rache/OneDrive - The University of Nottingham/MRes/Flow_Country_HSI_and_PSM/python_notebooks/hyperspectral_machine_learning/random_forest.py:40: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
#   row['model_result'].to_file(f"{output_directory}/{site_name}-{row['data_transformation']}-{row['spectrum']}-{test_size}-{max_depth}-{cv}-{formatted_date}.shp")
# /mnt/c/Users/rache/OneDrive - The University of Nottingham/MRes/Flow_Country_HSI_and_PSM/python_notebooks/hyperspectral_machine_learning/random_forest.py:40: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
#   row['model_result'].to_file(f"{output_directory}/{site_name}-{row['data_transformation']}-{row['spectrum']}-{test_size}-{max_depth}-{cv}-{formatted_date}.shp")
# /mnt/c/Users/rache/OneDrive - The University of Nottingham/MRes/Flow_Country_HSI_and_PSM/python_notebooks/hyperspectral_machine_learning/random_forest.py:40: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
#   row['model_result'].to_file(f"{output_directory}/{site_name}-{row['data_transformation']}-{row['spectrum']}-{test_size}-{max_depth}-{cv}-{formatted_date}.shp")
# /mnt/c/Users/rache/OneDrive - The University of Nottingham/MRes/Flow_Country_HSI_and_PSM/python_notebooks/hyperspectral_machine_learning/random_forest.py:40: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
#   row['model_result'].to_file(f"{output_directory}/{site_name}-{row['data_transformation']}-{row['spectrum']}-{test_size}-{max_depth}-{cv}-{formatted_date}.shp")
# /mnt/c/Users/rache/OneDrive - The University of Nottingham/MRes/Flow_Country_HSI_and_PSM/python_notebooks/hyperspectral_machine_learning/random_forest.py:40: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
#   row['model_result'].to_file(f"{output_directory}/{site_name}-{row['data_transformation']}-{row['spectrum']}-{test_size}-{max_depth}-{cv}-{formatted_date}.shp")
#                                          model_result spectrum  \
# 0          POINTID                        geometry...     full
# 1          POINTID                        geometry...      VIS
# 2          POINTID                        geometry...       RE
# 3          POINTID                        geometry...      NIR
# 4          POINTID                        geometry...     SWIR
# 5                                geometry   clf_pr...     full
# 6                                geometry   clf_pr...      VIS
# 7                                geometry   clf_pr...       RE
# 8                                geometry   clf_pr...      NIR
# 9                                geometry   clf_pr...     SWIR
# 10                               geometry   clf_pr...     full
# 11                               geometry   clf_pr...      VIS
# 12                               geometry   clf_pr...       RE
# 13                               geometry   clf_pr...      NIR
# 14                               geometry   clf_pr...     SWIR
# 15                               geometry clf_pred...     full
# 16                               geometry   clf_pr...      VIS
# 17                               geometry   clf_pr...       RE
# 18                               geometry   clf_pr...      NIR
# 19                               geometry   clf_pr...     SWIR
#
#    data_transformation  accuracy_mean  accuracy_standard_deviation
# 0             original       0.744828                     0.035166
# 1             original       0.648276                     0.062260
# 2             original       0.637931                     0.028850
# 3             original       0.606897                     0.025340
# 4             original       0.606897                     0.042792
# 5     first derivative       0.710345                     0.039917
# 6     first derivative       0.582759                     0.036818
# 7     first derivative       0.527586                     0.044428
# 8     first derivative       0.644828                     0.077567
# 9     first derivative       0.634483                     0.035166
# 10   second derivative       0.686207                     0.050444
# 11   second derivative       0.603448                     0.066329
# 12   second derivative       0.603448                     0.036166
# 13   second derivative       0.579310                     0.094183
# 14   second derivative       0.596552                     0.051839
# 15   continuum removal       0.675862                     0.078935
# 16   continuum removal       0.510345                     0.049492
# 17   continuum removal       0.555172                     0.066686
# 18   continuum removal       0.586207                     0.087235
# 19   continuum removal       0.624138                     0.078935

# %%
hml.random_forest.random_forest_csv_and_shape_file_outputs('erosion_updated', data_transformations, test_size=0.3, max_depth=4, output_directory='outputs', cv=5)
# Out:
# /home/rzw/.local/lib/python3.8/site-packages/sklearn/base.py:488: FutureWarning: The feature names should match those that were passed during fit. Starting version 1.2, an error will be raised.
# Feature names unseen at fit time:
# - 0
# - 1
# - 10
# - 100
# - 101
# - ...
# Feature names seen at fit time, yet now missing:
# - band1
# - band10
# - band100
# - band101
# - band102
# - ...
#
#   warnings.warn(message, FutureWarning)
# /home/rzw/.local/lib/python3.8/site-packages/sklearn/base.py:488: FutureWarning: The feature names should match those that were passed during fit. Starting version 1.2, an error will be raised.
# Feature names unseen at fit time:
# - 10
# - 11
# - 12
# - 13
# - 14
# - ...
# Feature names seen at fit time, yet now missing:
# - band10
# - band11
# - band12
# - band13
# - band14
# - ...
#
#   warnings.warn(message, FutureWarning)
# /home/rzw/.local/lib/python3.8/site-packages/sklearn/base.py:488: FutureWarning: The feature names should match those that were passed during fit. Starting version 1.2, an error will be raised.
# Feature names unseen at fit time:
# - 62
# - 63
# - 64
# - 65
# - 66
# - ...
# Feature names seen at fit time, yet now missing:
# - band63
# - band64
# - band65
# - band66
# - band67
# - ...
#
#   warnings.warn(message, FutureWarning)
# /home/rzw/.local/lib/python3.8/site-packages/sklearn/base.py:488: FutureWarning: The feature names should match those that were passed during fit. Starting version 1.2, an error will be raised.
# Feature names unseen at fit time:
# - 100
# - 101
# - 102
# - 103
# - 104
# - ...
# Feature names seen at fit time, yet now missing:
# - band100
# - band101
# - band102
# - band103
# - band104
# - ...
#
#   warnings.warn(message, FutureWarning)
# /home/rzw/.local/lib/python3.8/site-packages/sklearn/base.py:488: FutureWarning: The feature names should match those that were passed during fit. Starting version 1.2, an error will be raised.
# Feature names unseen at fit time:
# - 186
# - 187
# - 188
# - 189
# - 190
# - ...
# Feature names seen at fit time, yet now missing:
# - band187
# - band188
# - band189
# - band190
# - band191
# - ...
#
#   warnings.warn(message, FutureWarning)
# /home/rzw/.local/lib/python3.8/site-packages/sklearn/base.py:488: FutureWarning: The feature names should match those that were passed during fit. Starting version 1.2, an error will be raised.
# Feature names unseen at fit time:
# - 0
# - 1
# - 10
# - 100
# - 101
# - ...
# Feature names seen at fit time, yet now missing:
# - band1
# - band10
# - band100
# - band101
# - band102
# - ...
#
#   warnings.warn(message, FutureWarning)
# /home/rzw/.local/lib/python3.8/site-packages/sklearn/base.py:488: FutureWarning: The feature names should match those that were passed during fit. Starting version 1.2, an error will be raised.
# Feature names unseen at fit time:
# - 10
# - 11
# - 12
# - 13
# - 14
# - ...
# Feature names seen at fit time, yet now missing:
# - band10
# - band11
# - band12
# - band13
# - band14
# - ...
#
#   warnings.warn(message, FutureWarning)
# /home/rzw/.local/lib/python3.8/site-packages/sklearn/base.py:488: FutureWarning: The feature names should match those that were passed during fit. Starting version 1.2, an error will be raised.
# Feature names unseen at fit time:
# - 62
# - 63
# - 64
# - 65
# - 66
# - ...
# Feature names seen at fit time, yet now missing:
# - band63
# - band64
# - band65
# - band66
# - band67
# - ...
#
#   warnings.warn(message, FutureWarning)
# /home/rzw/.local/lib/python3.8/site-packages/sklearn/base.py:488: FutureWarning: The feature names should match those that were passed during fit. Starting version 1.2, an error will be raised.
# Feature names unseen at fit time:
# - 100
# - 101
# - 102
# - 103
# - 104
# - ...
# Feature names seen at fit time, yet now missing:
# - band100
# - band101
# - band102
# - band103
# - band104
# - ...
#
#   warnings.warn(message, FutureWarning)
# /home/rzw/.local/lib/python3.8/site-packages/sklearn/base.py:488: FutureWarning: The feature names should match those that were passed during fit. Starting version 1.2, an error will be raised.
# Feature names unseen at fit time:
# - 186
# - 187
# - 188
# - 189
# - 190
# - ...
# Feature names seen at fit time, yet now missing:
# - band187
# - band188
# - band189
# - band190
# - band191
# - ...
#
#   warnings.warn(message, FutureWarning)
# /home/rzw/.local/lib/python3.8/site-packages/sklearn/base.py:488: FutureWarning: The feature names should match those that were passed during fit. Starting version 1.2, an error will be raised.
# Feature names unseen at fit time:
# - 0
# - 1
# - 10
# - 100
# - 101
# - ...
# Feature names seen at fit time, yet now missing:
# - band1
# - band10
# - band100
# - band101
# - band102
# - ...
#
#   warnings.warn(message, FutureWarning)
# /home/rzw/.local/lib/python3.8/site-packages/sklearn/base.py:488: FutureWarning: The feature names should match those that were passed during fit. Starting version 1.2, an error will be raised.
# Feature names unseen at fit time:
# - 10
# - 11
# - 12
# - 13
# - 14
# - ...
# Feature names seen at fit time, yet now missing:
# - band10
# - band11
# - band12
# - band13
# - band14
# - ...
#
#   warnings.warn(message, FutureWarning)
# /home/rzw/.local/lib/python3.8/site-packages/sklearn/base.py:488: FutureWarning: The feature names should match those that were passed during fit. Starting version 1.2, an error will be raised.
# Feature names unseen at fit time:
# - 62
# - 63
# - 64
# - 65
# - 66
# - ...
# Feature names seen at fit time, yet now missing:
# - band63
# - band64
# - band65
# - band66
# - band67
# - ...
#
#   warnings.warn(message, FutureWarning)
# /home/rzw/.local/lib/python3.8/site-packages/sklearn/base.py:488: FutureWarning: The feature names should match those that were passed during fit. Starting version 1.2, an error will be raised.
# Feature names unseen at fit time:
# - 100
# - 101
# - 102
# - 103
# - 104
# - ...
# Feature names seen at fit time, yet now missing:
# - band100
# - band101
# - band102
# - band103
# - band104
# - ...
#
#   warnings.warn(message, FutureWarning)
# /home/rzw/.local/lib/python3.8/site-packages/sklearn/base.py:488: FutureWarning: The feature names should match those that were passed during fit. Starting version 1.2, an error will be raised.
# Feature names unseen at fit time:
# - 186
# - 187
# - 188
# - 189
# - 190
# - ...
# Feature names seen at fit time, yet now missing:
# - band187
# - band188
# - band189
# - band190
# - band191
# - ...
#
#   warnings.warn(message, FutureWarning)
# /mnt/c/Users/rache/OneDrive - The University of Nottingham/MRes/Flow_Country_HSI_and_PSM/python_notebooks/hyperspectral_machine_learning/random_forest.py:40: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
#   row['model_result'].to_file(f"{output_directory}/{site_name}-{row['data_transformation']}-{row['spectrum']}-{test_size}-{max_depth}-{cv}-{formatted_date}.shp")
# /mnt/c/Users/rache/OneDrive - The University of Nottingham/MRes/Flow_Country_HSI_and_PSM/python_notebooks/hyperspectral_machine_learning/random_forest.py:40: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
#   row['model_result'].to_file(f"{output_directory}/{site_name}-{row['data_transformation']}-{row['spectrum']}-{test_size}-{max_depth}-{cv}-{formatted_date}.shp")
# /mnt/c/Users/rache/OneDrive - The University of Nottingham/MRes/Flow_Country_HSI_and_PSM/python_notebooks/hyperspectral_machine_learning/random_forest.py:40: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
#   row['model_result'].to_file(f"{output_directory}/{site_name}-{row['data_transformation']}-{row['spectrum']}-{test_size}-{max_depth}-{cv}-{formatted_date}.shp")
# /mnt/c/Users/rache/OneDrive - The University of Nottingham/MRes/Flow_Country_HSI_and_PSM/python_notebooks/hyperspectral_machine_learning/random_forest.py:40: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
#   row['model_result'].to_file(f"{output_directory}/{site_name}-{row['data_transformation']}-{row['spectrum']}-{test_size}-{max_depth}-{cv}-{formatted_date}.shp")
# /mnt/c/Users/rache/OneDrive - The University of Nottingham/MRes/Flow_Country_HSI_and_PSM/python_notebooks/hyperspectral_machine_learning/random_forest.py:40: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
#   row['model_result'].to_file(f"{output_directory}/{site_name}-{row['data_transformation']}-{row['spectrum']}-{test_size}-{max_depth}-{cv}-{formatted_date}.shp")
#                                          model_result spectrum  \
# 0          POINTID                        geometry...     full
# 1          POINTID                        geometry...      VIS
# 2          POINTID                        geometry...       RE
# 3          POINTID                        geometry...      NIR
# 4          POINTID                        geometry...     SWIR
# 5                                geometry   clf_pr...     full
# 6                                geometry   clf_pr...      VIS
# 7                                geometry   clf_pr...       RE
# 8                                geometry   clf_pr...      NIR
# 9                                geometry   clf_pr...     SWIR
# 10                               geometry   clf_pr...     full
# 11                               geometry   clf_pr...      VIS
# 12                               geometry   clf_pr...       RE
# 13                               geometry   clf_pr...      NIR
# 14                               geometry   clf_pr...     SWIR
# 15                               geometry clf_pred...     full
# 16                               geometry   clf_pr...      VIS
# 17                               geometry   clf_pr...       RE
# 18                               geometry   clf_pr...      NIR
# 19                               geometry clf_pred...     SWIR
#
#    data_transformation  accuracy_mean  accuracy_standard_deviation
# 0             original       0.713789                     0.048406
# 1             original       0.627288                     0.039042
# 2             original       0.586625                     0.032116
# 3             original       0.577930                     0.046112
# 4             original       0.606832                     0.043223
# 5     first derivative       0.690807                     0.031907
# 6     first derivative       0.601242                     0.069592
# 7     first derivative       0.523230                     0.048122
# 8     first derivative       0.641739                     0.026222
# 9     first derivative       0.606832                     0.043223
# 10   second derivative       0.629938                     0.069503
# 11   second derivative       0.569400                     0.041951
# 12   second derivative       0.557930                     0.080974
# 13   second derivative       0.534617                     0.062174
# 14   second derivative       0.546335                     0.045306
# 15   continuum removal       0.592629                     0.040731
# 16   continuum removal       0.433540                     0.051095
# 17   continuum removal       0.451056                     0.047698
# 18   continuum removal       0.508903                     0.051609
# 19   continuum removal       0.560911                     0.070897

# %%
hml.random_forest.random_forest_csv_and_shape_file_outputs('erosion_updated', data_transformations, test_size=0.25, max_depth=4, output_directory='outputs', cv=5)
# Out:
# /home/rzw/.local/lib/python3.8/site-packages/sklearn/base.py:488: FutureWarning: The feature names should match those that were passed during fit. Starting version 1.2, an error will be raised.
# Feature names unseen at fit time:
# - 0
# - 1
# - 10
# - 100
# - 101
# - ...
# Feature names seen at fit time, yet now missing:
# - band1
# - band10
# - band100
# - band101
# - band102
# - ...
#
#   warnings.warn(message, FutureWarning)
# /home/rzw/.local/lib/python3.8/site-packages/sklearn/base.py:488: FutureWarning: The feature names should match those that were passed during fit. Starting version 1.2, an error will be raised.
# Feature names unseen at fit time:
# - 10
# - 11
# - 12
# - 13
# - 14
# - ...
# Feature names seen at fit time, yet now missing:
# - band10
# - band11
# - band12
# - band13
# - band14
# - ...
#
#   warnings.warn(message, FutureWarning)
# /home/rzw/.local/lib/python3.8/site-packages/sklearn/base.py:488: FutureWarning: The feature names should match those that were passed during fit. Starting version 1.2, an error will be raised.
# Feature names unseen at fit time:
# - 62
# - 63
# - 64
# - 65
# - 66
# - ...
# Feature names seen at fit time, yet now missing:
# - band63
# - band64
# - band65
# - band66
# - band67
# - ...
#
#   warnings.warn(message, FutureWarning)
# /home/rzw/.local/lib/python3.8/site-packages/sklearn/base.py:488: FutureWarning: The feature names should match those that were passed during fit. Starting version 1.2, an error will be raised.
# Feature names unseen at fit time:
# - 100
# - 101
# - 102
# - 103
# - 104
# - ...
# Feature names seen at fit time, yet now missing:
# - band100
# - band101
# - band102
# - band103
# - band104
# - ...
#
#   warnings.warn(message, FutureWarning)
# /home/rzw/.local/lib/python3.8/site-packages/sklearn/base.py:488: FutureWarning: The feature names should match those that were passed during fit. Starting version 1.2, an error will be raised.
# Feature names unseen at fit time:
# - 186
# - 187
# - 188
# - 189
# - 190
# - ...
# Feature names seen at fit time, yet now missing:
# - band187
# - band188
# - band189
# - band190
# - band191
# - ...
#
#   warnings.warn(message, FutureWarning)
# /home/rzw/.local/lib/python3.8/site-packages/sklearn/base.py:488: FutureWarning: The feature names should match those that were passed during fit. Starting version 1.2, an error will be raised.
# Feature names unseen at fit time:
# - 0
# - 1
# - 10
# - 100
# - 101
# - ...
# Feature names seen at fit time, yet now missing:
# - band1
# - band10
# - band100
# - band101
# - band102
# - ...
#
#   warnings.warn(message, FutureWarning)
# /home/rzw/.local/lib/python3.8/site-packages/sklearn/base.py:488: FutureWarning: The feature names should match those that were passed during fit. Starting version 1.2, an error will be raised.
# Feature names unseen at fit time:
# - 10
# - 11
# - 12
# - 13
# - 14
# - ...
# Feature names seen at fit time, yet now missing:
# - band10
# - band11
# - band12
# - band13
# - band14
# - ...
#
#   warnings.warn(message, FutureWarning)
# /home/rzw/.local/lib/python3.8/site-packages/sklearn/base.py:488: FutureWarning: The feature names should match those that were passed during fit. Starting version 1.2, an error will be raised.
# Feature names unseen at fit time:
# - 62
# - 63
# - 64
# - 65
# - 66
# - ...
# Feature names seen at fit time, yet now missing:
# - band63
# - band64
# - band65
# - band66
# - band67
# - ...
#
#   warnings.warn(message, FutureWarning)
# /home/rzw/.local/lib/python3.8/site-packages/sklearn/base.py:488: FutureWarning: The feature names should match those that were passed during fit. Starting version 1.2, an error will be raised.
# Feature names unseen at fit time:
# - 100
# - 101
# - 102
# - 103
# - 104
# - ...
# Feature names seen at fit time, yet now missing:
# - band100
# - band101
# - band102
# - band103
# - band104
# - ...
#
#   warnings.warn(message, FutureWarning)
# /home/rzw/.local/lib/python3.8/site-packages/sklearn/base.py:488: FutureWarning: The feature names should match those that were passed during fit. Starting version 1.2, an error will be raised.
# Feature names unseen at fit time:
# - 186
# - 187
# - 188
# - 189
# - 190
# - ...
# Feature names seen at fit time, yet now missing:
# - band187
# - band188
# - band189
# - band190
# - band191
# - ...
#
#   warnings.warn(message, FutureWarning)
# /home/rzw/.local/lib/python3.8/site-packages/sklearn/base.py:488: FutureWarning: The feature names should match those that were passed during fit. Starting version 1.2, an error will be raised.
# Feature names unseen at fit time:
# - 0
# - 1
# - 10
# - 100
# - 101
# - ...
# Feature names seen at fit time, yet now missing:
# - band1
# - band10
# - band100
# - band101
# - band102
# - ...
#
#   warnings.warn(message, FutureWarning)
# /home/rzw/.local/lib/python3.8/site-packages/sklearn/base.py:488: FutureWarning: The feature names should match those that were passed during fit. Starting version 1.2, an error will be raised.
# Feature names unseen at fit time:
# - 10
# - 11
# - 12
# - 13
# - 14
# - ...
# Feature names seen at fit time, yet now missing:
# - band10
# - band11
# - band12
# - band13
# - band14
# - ...
#
#   warnings.warn(message, FutureWarning)
# /home/rzw/.local/lib/python3.8/site-packages/sklearn/base.py:488: FutureWarning: The feature names should match those that were passed during fit. Starting version 1.2, an error will be raised.
# Feature names unseen at fit time:
# - 62
# - 63
# - 64
# - 65
# - 66
# - ...
# Feature names seen at fit time, yet now missing:
# - band63
# - band64
# - band65
# - band66
# - band67
# - ...
#
#   warnings.warn(message, FutureWarning)
# /home/rzw/.local/lib/python3.8/site-packages/sklearn/base.py:488: FutureWarning: The feature names should match those that were passed during fit. Starting version 1.2, an error will be raised.
# Feature names unseen at fit time:
# - 100
# - 101
# - 102
# - 103
# - 104
# - ...
# Feature names seen at fit time, yet now missing:
# - band100
# - band101
# - band102
# - band103
# - band104
# - ...
#
#   warnings.warn(message, FutureWarning)
# /home/rzw/.local/lib/python3.8/site-packages/sklearn/base.py:488: FutureWarning: The feature names should match those that were passed during fit. Starting version 1.2, an error will be raised.
# Feature names unseen at fit time:
# - 186
# - 187
# - 188
# - 189
# - 190
# - ...
# Feature names seen at fit time, yet now missing:
# - band187
# - band188
# - band189
# - band190
# - band191
# - ...
#
#   warnings.warn(message, FutureWarning)
# /mnt/c/Users/rache/OneDrive - The University of Nottingham/MRes/Flow_Country_HSI_and_PSM/python_notebooks/hyperspectral_machine_learning/random_forest.py:40: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
#   row['model_result'].to_file(f"{output_directory}/{site_name}-{row['data_transformation']}-{row['spectrum']}-{test_size}-{max_depth}-{cv}-{formatted_date}.shp")
# /mnt/c/Users/rache/OneDrive - The University of Nottingham/MRes/Flow_Country_HSI_and_PSM/python_notebooks/hyperspectral_machine_learning/random_forest.py:40: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
#   row['model_result'].to_file(f"{output_directory}/{site_name}-{row['data_transformation']}-{row['spectrum']}-{test_size}-{max_depth}-{cv}-{formatted_date}.shp")
# /mnt/c/Users/rache/OneDrive - The University of Nottingham/MRes/Flow_Country_HSI_and_PSM/python_notebooks/hyperspectral_machine_learning/random_forest.py:40: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
#   row['model_result'].to_file(f"{output_directory}/{site_name}-{row['data_transformation']}-{row['spectrum']}-{test_size}-{max_depth}-{cv}-{formatted_date}.shp")
# /mnt/c/Users/rache/OneDrive - The University of Nottingham/MRes/Flow_Country_HSI_and_PSM/python_notebooks/hyperspectral_machine_learning/random_forest.py:40: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
#   row['model_result'].to_file(f"{output_directory}/{site_name}-{row['data_transformation']}-{row['spectrum']}-{test_size}-{max_depth}-{cv}-{formatted_date}.shp")
# /mnt/c/Users/rache/OneDrive - The University of Nottingham/MRes/Flow_Country_HSI_and_PSM/python_notebooks/hyperspectral_machine_learning/random_forest.py:40: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
#   row['model_result'].to_file(f"{output_directory}/{site_name}-{row['data_transformation']}-{row['spectrum']}-{test_size}-{max_depth}-{cv}-{formatted_date}.shp")
#                                          model_result spectrum  \
# 0          POINTID                        geometry...     full
# 1          POINTID                        geometry...      VIS
# 2          POINTID                        geometry...       RE
# 3          POINTID                        geometry...      NIR
# 4          POINTID                        geometry...     SWIR
# 5                                geometry   clf_pr...     full
# 6                                geometry   clf_pr...      VIS
# 7                                geometry   clf_pr...       RE
# 8                                geometry   clf_pr...      NIR
# 9                                geometry   clf_pr...     SWIR
# 10                               geometry   clf_pr...     full
# 11                               geometry   clf_pr...      VIS
# 12                               geometry   clf_pr...       RE
# 13                               geometry   clf_pr...      NIR
# 14                               geometry   clf_pr...     SWIR
# 15                               geometry clf_pred...     full
# 16                               geometry   clf_pr...      VIS
# 17                               geometry   clf_pr...       RE
# 18                               geometry   clf_pr...      NIR
# 19                               geometry   clf_pr...     SWIR
#
#    data_transformation  accuracy_mean  accuracy_standard_deviation
# 0             original       0.682759                     0.043069
# 1             original       0.593103                     0.035502
# 2             original       0.582759                     0.039917
# 3             original       0.603448                     0.036166
# 4             original       0.555172                     0.025340
# 5     first derivative       0.637931                     0.036166
# 6     first derivative       0.520690                     0.035166
# 7     first derivative       0.517241                     0.037774
# 8     first derivative       0.617241                     0.029663
# 9     first derivative       0.572414                     0.050444
# 10   second derivative       0.665517                     0.080575
# 11   second derivative       0.562069                     0.082759
# 12   second derivative       0.572414                     0.078178
# 13   second derivative       0.572414                     0.076642
# 14   second derivative       0.551724                     0.048766
# 15   continuum removal       0.648276                     0.065969
# 16   continuum removal       0.448276                     0.047531
# 17   continuum removal       0.503448                     0.050444
# 18   continuum removal       0.572414                     0.042792
# 19   continuum removal       0.610345                     0.049492
